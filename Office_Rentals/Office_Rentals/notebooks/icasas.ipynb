# %% [markdown]
# # WebScraping a icasas

# %% [markdown]
# ### Importamos las librerias necesarias para poder continuar

# %%
#Importamos las librerias de para la extracion de datos
import webbrowser

#importamos requests
import requests

#Importamos lxml para un buen manejo de datos
import lxml.html as html

# %% [markdown]
# ### Empezamos el proceso de conexion de datos con la pagina

# %%
#Recopilamos los datos con reequests:
r = requests.get('https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0')

#Vizualizamos los datos una vez ya obtenidos los datos:
w = webbrowser.open_new('https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0')

# %%
#Obtenemos los datos:
print(len(r.text))
# Out:
# 70256

# %% [markdown]
# ##### En teoria ya podremos extraer nuestros datos, con requests podemos extraer datos y mandarlos en un archivo .text donde estaran todos nuestros datos ya pedidos anteriormente.

# %%
r.text
# Out:
#   File "C:\Users\j0rge\AppData\Local\Temp/ipykernel_17244/2484721818.py", line 1
#     path = 'C:\Users\j0rge\OneDrive\Escritorio\Portafolio\Office_Rentals\Office_Rentals\docs'
#                                                                                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ### Ahora vamos a seleccionar los datos que espesificamente vayamos a utilizar
# #### Tendremos que importar las librerias para poder tranformar el html a text

# %%
#Traimos desde la raiz bs4 para poder importar BeautifulSoup
from bs4 import BeautifulSoup

# %% [markdown]
# ### Ahora vamos a convertir el HTML a text con BeautifulSoup

# %%
#Estamos transformando los datos javascript a text
b = BeautifulSoup(r.text, 'lxml')

# %%
#Obetenmos los datos a Text
type(b)
# Out:
# bs4.BeautifulSoup

# %%
t = print(b.title)
# Out:
# <title>32 oficinas en renta en Acapulco de Juárez - icasas.mx</title>

# %%
ts = print(b.title.string)
# Out:
# 32 oficinas en renta en Acapulco de Juárez - icasas.mx

# %%
print(b.p)
# Out:
# <p>&lt;![if !IE]&gt;&lt;![endif]&gt;</p>

# %%
print(b.p.text)
# Out:
# <![if !IE]><![endif]>

# %%
print(b.p.string)
# Out:
# <![if !IE]><![endif]>

# %%
print(b.a)
# Out:
# <a href="/politicaCookies" target="_blank">Política de Cookies</a>

# %%
print(b.a.['title'])
# Out:
#   File "C:\Users\j0rge\AppData\Local\Temp/ipykernel_608/3778999611.py", line 1
#     print(b.a.['title'])
#               ^
# SyntaxError: invalid syntax

# %%
print(b.p.parent)
# Out:
# <body><p>&lt;![if !IE]&gt;&lt;![endif]&gt;</p><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="es_MX" http-equiv="content-language"/><meta content="no-cache" http-equiv="Pragma"/><meta content="no-cache" http-equiv="Cache-Control"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-152x152_v2.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-144x144_v2.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-120x120_v2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-114x114_v2.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-72x72_v2.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-57x57_v2.png" rel="apple-touch-icon-precomposed" sizes="57x57"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-32x32_v2.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-48x48_v2.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-64x64_v2.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-32x32_v2.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
# <script>var userLogged=false;</script>
# <title>32 oficinas en renta en Acapulco de Juárez - icasas.mx</title>
# <meta content="index,follow" name="robots"/>
# <meta content="comerciales oficinas-guerrero-acapulco-juarez" name="keywords"/>
# <link href="https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" rel="canonical"/>
# <link href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0/p_2" rel="next"/>
# <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" name="title"/>
# <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" name="description"/>
# <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" property="og:title"/>
# <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" property="og:description"/>
# <meta content="https://script.resemmedia.com/images/images/logo-arrows_v1_big.png" property="og:image"/>
# <meta content="https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" property="og:url"/>
# <meta content="es_MX" property="og:locale"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@icasasmex" name="twitter:site"/>
# <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" name="twitter:title"/>
# <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" name="twitter:description"/>
# <meta content="https://script.resemmedia.com/images/images/logo-arrows_v1_big.png" name="twitter:image"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="app-id=com.resem.app.mx" name="google-play-app"/>
# <link href="android-app://com.resem.app.mx/https/www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" rel="alternate"/>
# <meta content="app-id=1093781012" name="apple-itunes-app"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://script.resemmedia.com" rel="preconnect"/>
# <link href="https://d2op7us8chplo5.cloudfront.net" rel="preconnect"/>
# <link href="https://apis.google.com" rel="preconnect"/>
# <link href="https://accounts.google.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://connect.facebook.net" rel="preconnect"/>
# <link href="https://www.facebook.com" rel="preconnect"/>
# <link href="https://cdn.ampproject.org" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://www.gstatic.com" rel="preconnect"/>
# <link href="https://www.googletagservices.com" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
# <link href="https://adservice.google.com" rel="preconnect"/>
# <link as="script" href="https://www.google-analytics.com/analytics.js" rel="preload"/>
# <link as="script" href="https://www.googletagservices.com/tag/js/gpt.js" rel="preload"/>
# <link as="script" href="https://script.resemmedia.com/script/script/listing.min_v136.js" rel="preload"/>
# <link as="style" href="https://script.resemmedia.com/style/style/listing.min_v99.css" rel="preload"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600&amp;display=swap" rel="preload"/>
# <link as="image" href="https://script.resemmedia.com/images/images/logo-icasas_v4.png" rel="preload"/>
# <link as="image" href="https://script.resemmedia.com/images/images/loading-image-v2.svg" rel="preload"/>
# <link as="image" href="https://script.resemmedia.com/images/images/web/no-image_v2.png" rel="preload"/>
# <link as="image" href="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjUyMzEvLTI5OTg1NjE1OS5qcGciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjM1NCwiaGVpZ2h0IjoyNDAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" rel="preload"/>
# <link as="image" href="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjE1NjA4ODkyMjYyODhfMTYzOTU4NDkzMi5qcGVnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjozNTAsImhlaWdodCI6MTAwLCJmaXQiOiJpbnNpZGUiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" rel="preload"/>
# <style>
#     @import url(https://fonts.googleapis.com/css?family=Open+Sans:300,400,600&display=swap);@import url(https://script.resemmedia.com/fonts/fonts/font_icomoon_6rah64.css);body,select option,ul{padding:0;margin:0}#smartbanner,.filtro,body{overflow:hidden}.filtro .filtro-wrapper form,.slick-loading .slick-slide,.slick-loading .slick-track{visibility:hidden}html{height:100%}*,:after,:before{box-sizing:inherit}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,form,h1,h2,h3,h4,h5,h6,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline;box-sizing:border-box}#smartbanner,.slick-next:before,.slick-prev:before,body{-webkit-font-smoothing:antialiased}.ui-button-1,.ui-text-white-1{font-size:16px;font-weight:700}body{height:100vh;width:100%;position:relative;font-size:16px;color:#343434;overflow-y:scroll;font-family:"Open Sans",sans-serif,Arial,Helvetica}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:'';content:none}table{border-collapse:collapse;border-spacing:0}del{text-decoration:line-through}abbr[title],dfn[title]{border-bottom:1px dotted;cursor:help}article,aside,details,figcaption,figure,hgroup,main,menu,nav,section{display:block}button,input[type=text],input[type=email],input[type=tel],input[type=password],input[type=checkbox],input[type=number],input[type=submit],select{-webkit-appearance:none;-moz-appearance:none;appearance:none;border:0;outline:0;border-radius:0;-webkit-font-smoothing:antialiased}.uExternalRefresh,a,button,input[type=submit]{cursor:pointer}.ui-link-0{text-decoration:none}.ui-text-white-1{color:#fff;line-height:22px}.flex-center,.flex-center.ui-button-1{display:flex;align-items:center;justify-content:center}.has-error{border:2px solid #ec8f96!important;background-color:#fae3e5!important}.sprite{background-image:url(https://script.resemmedia.com/images/images/new_design/common/sprite_detail_v3.svg);color:transparent;display:block}.ui-button-1{width:100%;min-height:40px;background-color:#87c535;color:#fff;line-height:40px;text-align:center;display:block;border:0;border-radius:25px}.ui-button-1:hover{background-color:#ade05c}@-webkit-keyframes rotation{from{-webkit-transform:rotate(0)}to{-webkit-transform:rotate(359deg)}}.grecaptcha-badge{display:none}#smartbanner{position:absolute;left:0;top:-82px;width:100%;height:78px;z-index:9998;-webkit-text-size-adjust:none;background:#fff;border-bottom:1px solid #e0e0e0}#smartbanner .sb-container{margin:0 auto}#smartbanner .sb-container .sb-close{position:absolute;left:5px;top:5px;display:block;font-size:15px;text-align:center;text-decoration:none;text-shadow:none;border-radius:14px;-webkit-font-smoothing:subpixel-antialiased;border:0;width:17px;height:17px;line-height:17px;color:#343434;background:0 0;box-shadow:none;padding:25px 10px}#smartbanner .sb-container .sb-button,#smartbanner .sb-container .sb-info{position:absolute;text-shadow:0 1px 0 rgba(255,255,255,.8);font-weight:700}#smartbanner .sb-container .sb-icon{position:absolute;left:30px;top:10px;display:block;width:57px;height:57px;background-size:cover;border:none}#smartbanner .sb-container .sb-info{left:98px;top:18px;width:44%;font-size:11px;line-height:1.2em;color:#343434}#smartbanner .sb-container .sb-info strong{color:#4d75b7;display:block;font-size:13px;line-height:18px}#smartbanner .sb-container .sb-info>span{display:block}#smartbanner .sb-container .sb-button{border:none;min-width:12%;padding:1px;background:0 0;box-shadow:none;min-height:28px;right:20px;top:24px;height:24px;font-size:14px;line-height:24px;text-align:center;text-transform:uppercase;text-decoration:none}#smartbanner .sb-container .sb-button span{text-a ...
# <script defer="">
# 	(function (d,b,l,c,k) {k = document.createElement(l);k.src = b;k.defer = true;d.getElementsByTagName(c)[0].appendChild(k);})(document, "https://www.googletagservices.com/tag/js/gpt.js", "script", "head");
# 	window.googletag = window.googletag || {cmd: []};
# </script>
# <script defer="" type="text/javascript">
# 	var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# 	googletag.cmd.push(function() {
# 	//mapping size for responsive banners
# 	var mapping = googletag.sizeMapping().
# 		addSize([320, 400], [320, 90]).
# 		addSize([498, 400], [498, 90]).
# 		addSize([728, 400], [728, 90]).
# 		build();
#
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD3', [[728, 90],[840, 140],[860, 90],[570, 165],], 'list_third_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE3_SEARCH', [[300, 100],[250, 250],[250, 300],[300, 250],[300, 300],[300, 600],], 'list_third_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE1_SEARCH', [[250, 250],[300, 250],[300, 300],[300, 100],[250, 300],[300, 600],], 'list_first_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD1', [[960, 90],[728, 90],[860, 90],[970, 90],[498, 90],[860, 200],], 'list_first_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD2', [[498, 90],[970, 90],[728, 90],[960, 90],[860, 90],], 'list_second_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE4_SEARCH', [[300, 100],[300, 300],[300, 250],[250, 250],[250, 300],[300, 600],], 'list_fourth_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE2_SEARCH', [[300, 250],[300, 300],[250, 300],[300, 600],[250, 250],[300, 100],], 'list_second_filter').addService(googletag.pubads());
#
#     googletag.defineSlot('/1241729/TEXT_PRICE', [220, 30], 'div-gpt-ad-1469602311097-0').addService(googletag.pubads());
#     googletag.defineSlot('/1241729/TEXT_SERVICE_1', [220, 30], 'div-gpt-ad-1469602311097-1').addService(googletag.pubads());
#
# 	googletag.pubads().setTargeting("RESEM_OPERATION_TYPE",['renta']);
#
# 	googletag.pubads().setTargeting("RESEM_PROPERTY_TYPE",['oficina']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_1",['guerrero']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_2",['acapulco-juarez']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_0",['MX']);
#   	googletag.pubads().enableSingleRequest();
#   	googletag.pubads().collapseEmptyDivs();
#   	googletag.pubads().enableSyncRendering();
#  	googletag.enableServices();
# });
# 	</script><script async="" type="text/javascript">
#     var isIE10 = false;
#     /*@cc_on
#         if (/^10/.test(@_jscript_version)) {
#             isIE10 = true;
#         }
#     @*/
#     if (isIE10) {
#         document.write("<link rel='stylesheet' href='/www/resem/new_design/listing/css/ie10.css'>");
#     }
# </script>
# <script async="">
# 	var UA ="UA-42400835-1";
#
# 	var UAGlobal = "UA-42400835-14";
#
# 	var UAPlatform = "UA-158549811-8";
#
# 	var UACountryCode = "mx";
#
#
# 	var linkerDomains = ['puntopropiedad.com','icasas.cl','persquare.co.za','laencontre.com.pe','icasas.ec','icasas.com.pa','icasas.co.cr','imocasa.com.br','icasas.com.ar','globaliza.com'];
# 	var userId = "0";
#
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', UA, 'auto', {'allowLinker': true});
# 	ga('require', 'linker');
# 	ga('linker:autoLink', linkerDomains);
#
#
# 	ga('create', UAGlobal, 'auto', {'name':'global'});
# 	// Para lanzar el UA necesita tener un evento, puede que se lance en resem-analytics , usar pluggin Google Analytics Debugger
# 	if (typeof UAPlatform !== 'undefined') {
# 		ga('create', UAPlatform, 'auto', {'name':'platform'});
# 	}
# </script>
# <!-- Facebook Pixel Code -->
# <script async="">
# 	!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.defer=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 	fbq('init', '301253267239153');
# 	fbq('track', "PageView");
#
# 	fbq('init', '102954430074060');
# 	fbq('track', "PageView");
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=301253267239153&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/><img height="1" src="https://www.facebook.com/tr?id=102954430074060&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code --><script>
#     var adas = "2f7777772f726573656d2f6e65775f64657369676e2f6c697374696e672f696e636c7564652f6c697374696e672d61642e6a7370";
# </script>
# <script>const awp = 'listing';</script>
# <meta content="qndwlng7i8ppoj69vp0aem6hqouzsi" name="facebook-domain-verification"/>
# <div class="menu__layer"></div><div class="visible" id="avisoLegalCookies" onclick="ocultaAviso();">
# 	icasas utiliza sus propias cookies y las de terceros para elaborar información estadística y así mostrarte publicidad relacionada con tus búsquedas. Al continuar navegando aceptas su uso. Puedes obtener más información aquí:
# 	<a href="/politicaCookies" target="_blank">Política de Cookies</a>
# </div>
# <header><div class="js-menu maxWidth">
# <div class="content-logo">
# <div class="div-logo" itemscope="" itemtype="https://schema.org/Organization">
# <a class="ui-link-0" href="/">
# <img alt="Casas en venta y renta en México - icasas.mx" class="logo" itemprop="logo" src="https://script.resemmedia.com/images/images/logo-icasas_v4.png"/>
# <meta content="https://www.icasas.mx/" itemprop="url"/>
# </a>
# </div>
# </div>
# <i class="icon-r-menu" id="openHeaderMenuMobile"></i>
# <ul class="items-list"><li class="items-list__item">
# <div class="js-dropdown modulo dropdown blue">
# <button class="dropdown__btn-select" type="button">
# <span class="text">MX$</span>
# </button>
# <ul class="dropdown__list alt-col js-nice">
# <li class="dropdown__list__item currency-selector" data-id="" data-val="MXN">MX$</li>
# <li class="dropdown__list__item currency-selector" data-id="" data-val="USD">US$</li></ul>
# </div>
# </li><li class="items-list__item">
# <a class="icon login" href="#">
# <span class="text ui-text-white-1" data-login="Login" data-my-account="Mi cuenta">Login</span>
# <span class="icon-r-user login"></span>
# </a>
# </li></ul>
# </div></header>
# <div id="g_prompt" style="position:absolute; float:right; top:25px;"></div>
# <div class="menu">
# <div class="menu__arrow">
# <a class="ui-link-0" href="#">
# <div></div>
# </a>
# </div>
# <div class="menu__title">
# <p class="ui-titular-1">Iniciar sesión en Icasas México</p>
# </div>
# <div class="menu__login">
# <form action="/clientLoginServlet" class="login" method="post">
# <div class="login__title ui-titular-2">Cuenta de usuario</div>
# <div class="login__wrapper">
# <p class="error display-none" id="loginFail"></p>
# <div class="input-form">
# <input id="loginMail" name="email" placeholder="Email" type="email" value=""/></div>
# <div class="input-form">
# <input id="loginPassword" name="pwd" placeholder="Contraseña" type="password"/>
# </div>
# <div class="input-form">
# <button class="ui-button-1" id="loginButton">Ingresar</button>
# </div>
# <!-- 				<div class="g-signin2" data-width="300" data-height="40" data-longtitle="true" data-theme="dark" data-onsuccess="gSignIn" async defer></div> -->
# <div async="" defer="" id="myGoogleButton"></div>
# <div class="input-form text-center">
# <a class="ui-text-grey-1" id="recoverPassword">Recuperar contraseña</a>
# </div>
# </div>
# </form>
# </div>
# <div class="menu__registration">
# <span class="ui-text-grey-1">¿Necesitas una cuenta?</span>
# <a class="ui-text-blue-1" data-where="listing" id="signUp">Registrarse</a>
# </div>
# </div>
# <script>
# 		var loginButtonTextLogin = 'Login';
# 		var loginButtonTextMyaccount = 'Mi cuenta';
# 	</script>
# <nav class="migas" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <ul class="detail-pagination">
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/" itemprop="item" title="icasas"><span itemprop="name">icasas</span><i class="icon-r-chevron-right"></i></a>
# <meta content="1" itemprop="position"/>
# </li>
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/renta/comerciales-oficinas-3_14_0_0_0_0" itemprop="item" title="Oficinas en Renta"><span itemprop="name">Oficinas en Renta</span><i class="icon-r-chevron-right"></i></a>
# <meta content="2" itemprop="position"/>
# </li>
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/renta/comerciales-oficinas-guerrero-3_14_12_0_0_0" itemprop="item" title="Guerrero"><span itemprop="name">Guerrero</span><i class="icon-r-chevron-right"></i></a>
# <meta content="3" itemprop="position"/>
# </li>
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" itemprop="item" title="Acapulco de Juárez"><span itemprop="name">Acapulco de Juárez</span><i class="icon-r-chevron-right"></i></a>
# <meta content="4" itemprop="position"/>
# </li>
# </ul>
# </nav>
# <div class="container-body listado">
# <div class="aside">
# <div class="alert floating-alert desktop">
# <span class="text-hide">Te avisamos de nuevos anuncios en tu mail:</span>
# <button class="create-alert-visitor" data-origin="LB" data-text="Crear alerta" data-text-small="Crear alerta"></button>
# </div>
# <aside class="filtro">
# <div class="cabeza">
# <div class="filtrar">FILTRA TU BÚSQUEDA<i class="icon-r-cross cerrar-filtro"></i></div>
# </div>
# <div class="filtro-wrapper">
# <form class="ui-form-1">
# <div class="regiones-wrapper mostrar provincia-dropw" data-ae="location">
# <div class="regiones-pestana provincia-dropp">
# <h3 class="title">Barrio
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d61636170756c636f2d6a756172657a2d63656e74726f2d335f31345f31325f305f3336365f343431">
# <label class="labe1" for="checkbox-7386"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-acapulco-juarez-centro-3_14_12_0_366_441" title="Acapulco de Juárez Centro">Acapulco de Juárez Centro (2)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d636f6e646573612d335f31345f31325f305f3336365f32393738">
# <label class="labe1" for="checkbox-12021"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-condesa-3_14_12_0_366_2978" title="Condesa">Condesa (1)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d636f7374612d617a756c2d335f31345f31325f305f3336365f313030">
# <label class="labe1" for="checkbox-12224"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-costa-azul-3_14_12_0_366_100" title="Costa Azul">Costa Azul (2)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d686f726e6f732d696e73757267656e7465732d335f31345f31325f305f3336365f31373039">
# <label class="labe1" for="checkbox-17139"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-hornos-insurgentes-3_14_12_0_366_1709" title="Hornos Insurgentes">Hornos Insurgentes (3)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d6d6167616c6c616e65732d335f31345f31325f305f3336365f32393732">
# <label class="labe1" for="checkbox-23745"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-magallanes-3_14_12_0_366_2972" title="Magallanes">Magallanes (2)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d6e7565766f2d63617961636f2d335f31345f31325f305f3336365f3131333437">
# <label class="labe1" for="checkbox-25643"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-nuevo-cayaco-3_14_12_0_366_11347" title="Nuevo Cayaco">Nuevo Cayaco (2)
#                     </a>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper mostrar tipo-dropw" data-ae="type">
# <div class="regiones-pestana tipo-dropp">
# <h3 class="title">Tipo de inmueble
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d656469666963696f732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31355f31325f305f3336365f30">
# <label class="labe1" for="checkbox-15"></label>
# <a class="linkFilter" href="/renta/comerciales-edificios-guerrero-acapulco-juarez-3_15_12_0_366_0" title="Edificio">Edificios (7)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d677565727265726f2d61636170756c636f2d6a756172657a2d325f305f31325f305f3336365f30">
# <label class="labe1" for="checkbox-2"></label>
# <a class="linkFilter" href="/renta/habitacionales-guerrero-acapulco-juarez-2_0_12_0_366_0" title="Habitacional">Habitacionales (1,939)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d696e6d7565626c65732d70726f6475637469766f732d757262616e6f732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31375f31325f305f3336365f30">
# <label class="labe1" for="checkbox-17"></label>
# <a class="linkFilter" href="/renta/comerciales-inmuebles-productivos-urbanos-guerrero-acapulco-juarez-3_17_12_0_366_0" title="Inmuebles productivos urbanos">Inmuebles productivos urbanos (3)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6c6f63616c65732d636f6d65726369616c65732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31305f31325f305f3336365f30">
# <label class="labe1" for="checkbox-10"></label>
# <a class="linkFilter" href="/renta/comerciales-locales-comerciales-guerrero-acapulco-juarez-3_10_12_0_366_0" title="Local comercial">Locales Comerciales (227)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f746965727261732d6c6f7465732d74657272656e6f732d677565727265726f2d61636170756c636f2d6a756172657a2d355f395f31325f305f3336365f30">
# <label class="labe1" for="checkbox-9"></label>
# <a class="linkFilter" href="/renta/tierras-lotes-terrenos-guerrero-acapulco-juarez-5_9_12_0_366_0" title="Lote de Terreno">Lotes de Terrenos (37)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f696e647573747269616c65732d6e617665732d677565727265726f2d61636170756c636f2d6a756172657a2d345f32305f31325f305f3336365f30">
# <label class="labe1" for="checkbox-20"></label>
# <a class="linkFilter" href="/renta/industriales-naves-guerrero-acapulco-juarez-4_20_12_0_366_0" title="Nave">Naves (28)
#                     </a>
# </li>
# <li class="regiones iCheck">
# <label class="labe1 checkSelected" for="checkbox-14"></label>
# <span class="spanFilter" title="Oficina">Oficinas (32)</span>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper mostrar sudtipo-dropw" data-ae="subtype">
# <div class="regiones-pestana sudtipo-dropp">
# <h3 class="title">Otros tipos de propiedad
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d63617361732d677565727265726f2d61636170756c636f2d6a756172657a2d325f355f31325f305f3336365f30">
# <label class="labe1" for="checkbox-5"></label>
# <a class="linkFilter" href="/renta/habitacionales-casas-guerrero-acapulco-juarez-2_5_12_0_366_0" title="Casa">Casas (687)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d63617361732d636f6e646f6d696e696f2d677565727265726f2d61636170756c636f2d6a756172657a2d325f375f31325f305f3336365f30">
# <label class="labe1" for="checkbox-7"></label>
# <a class="linkFilter" href="/renta/habitacionales-casas-condominio-guerrero-acapulco-juarez-2_7_12_0_366_0" title="Casa en condominio">Casas condominio (57)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d646570617274616d656e746f732d677565727265726f2d61636170756c636f2d6a756172657a2d325f335f31325f305f3336365f30">
# <label class="labe1" for="checkbox-3"></label>
# <a class="linkFilter" href="/renta/habitacionales-departamentos-guerrero-acapulco-juarez-2_3_12_0_366_0" title="Departamento">Departamentos (1,153)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d7175696e7461732d677565727265726f2d61636170756c636f2d6a756172657a2d325f345f31325f305f3336365f30">
# <label class="labe1" for="checkbox-4"></label>
# <a class="linkFilter" href="/renta/habitacionales-quintas-guerrero-acapulco-juarez-2_4_12_0_366_0" title="Quinta">Quintas (13)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d76696c6c61732d677565727265726f2d61636170756c636f2d6a756172657a2d325f315f31325f305f3336365f30">
# <label class="labe1" for="checkbox-1"></label>
# <a class="linkFilter" href="/renta/habitacionales-villas-guerrero-acapulco-juarez-2_1_12_0_366_0" title="Villa">Villas (29)
#                     </a>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper mostrar confoto" data-ae="other">
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f666f746f73">
# <label class="labe1" for="checkbox-1640973709568"></label>
# <span class="spanFilter" title="Fotos">Fotos</span>
# </li>
# </ul>
# </div>
# <div class="precios-wrapper" id="precios-wrapper">
# <div class="regiones-wrapper preciomax" data-ae="priceMin">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Precio Mín.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="priceMin" name="priceMin" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="price-min">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d70726563696f" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d70726563696f" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d70726563696f" title="1,000">1,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313530302d70726563696f" title="1,500">1,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f323030302d70726563696f" title="2,000">2,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f323530302d70726563696f" title="2,500">2,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f333030302d70726563696f" title="3,000">3,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f333530302d70726563696f" title="3,500">3,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f343030302d70726563696f" title="4,000">4,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f353030302d70726563696f" title="5,000">5,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f373030302d70726563696f" title="7,000">7,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31303030302d70726563696f" title="10,000">10,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31323030302d70726563696f" title="12,000">12,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31353030302d70726563696f" title="15,000">15,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31373030302d70726563696f" title="17,000">17,000</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="regiones-wrapper preciomax" data-ae="priceMax">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Precio Máx.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="priceMax" name="priceMax" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="price-max">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d3230302d70726563696f" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d3530302d70726563696f" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d313030302d70726563696f" title="1,000">1,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d313530302d70726563696f" title="1,500">1,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d323030302d70726563696f" title="2,000">2,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d323530302d70726563696f" title="2,500">2,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d333030302d70726563696f" title="3,000">3,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d333530302d70726563696f" title="3,500">3,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d343030302d70726563696f" title="4,000">4,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d353030302d70726563696f" title="5,000">5,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d373030302d70726563696f" title="7,000">7,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31303030302d70726563696f" title="10,000">10,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31323030302d70726563696f" title="12,000">12,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31353030302d70726563696f" title="15,000">15,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31373030302d70726563696f" title="17,000">17,000</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="precios-wrapper" id="surface-wrapper">
# <div class="regiones-wrapper preciomax" data-ae="surfaceMin">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Área Min.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="surfaceMin" name="surfaceMin" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="surface-min">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f35302d6d32" title="50">50</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3130302d6d32" title="100">100</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3135302d6d32" title="150">150</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d6d32" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3235302d6d32" title="250">250</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3330302d6d32" title="300">300</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d6d32" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d6d32" title="1,000">1,000</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="regiones-wrapper preciomax" data-ae="surfaceMax">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Área Máx.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="surfaceMax" name="surfaceMax" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="surface-max">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f35302d6d32" title="50">50</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3130302d6d32" title="100">100</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3135302d6d32" title="150">150</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d6d32" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3235302d6d32" title="250">250</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3330302d6d32" title="300">300</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d6d32" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d6d32" title="1,000">1,000</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="prestas-flex">
# <div class="regiones-wrapper presta-dropw mostrar" data-ae="rooms">
# <div class="regiones-pestana presta-dropp">
# <div class="title"><i class="icon-r-bed"></i></div>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f312d726563616d617261">
# <label class="labe1" for="checkbox-1"></label>
# <span class="spanFilter" title="1">1</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f322d726563616d61726173">
# <label class="labe1" for="checkbox-2"></label>
# <span class="spanFilter" title="2">2</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f332d726563616d61726173">
# <label class="labe1" for="checkbox-3"></label>
# <span class="spanFilter" title="3">3</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f342d726563616d61726173">
# <label class="labe1" for="checkbox-4"></label>
# <span class="spanFilter" title="4">4</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f352d726563616d61726173">
# <label class="labe1" for="checkbox-5"></label>
# <span class="spanFilter" title="5">5</span>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper presta-dropw mostrar" data-ae="bathrooms">
# <div class="regiones-pestana presta-dropp">
# <div class="title"><i class="icon-r-bathroom"></i></div>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f312d62616e6f">
# <label class="labe1" for="checkbox-1"></label>
# <span class="spanFilter" title="1">1</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f322d62616e6f73">
# <label class="labe1" for="checkbox-2"></label>
# <span class="spanFilter" title="2">2</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f332d62616e6f73">
# <label class="labe1" for="checkbox-3"></label>
# <span class="spanFilter" title="3">3</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f342d62616e6f73">
# <label class="labe1" for="checkbox-4"></label>
# <span class="spanFilter" title="4">4</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f352d62616e6f73">
# <label class="labe1" for="checkbox-5"></label>
# <span class="spanFilter" title="5">5</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="regiones-wrapper mostrar sudtipo-dropw" data-ae="dateeAdded">
# <div class="regiones-pestana sudtipo-dropp">
# <h3 class="title">Fecha de publicación
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f30">
# <label class="labe1 checkSelected" for="checkbox-1640973709574"></label>
# <span class="spanFilter" title="Indiferente">Indiferente</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f756c74696d61732d34382d686f7261732d7075626c69636163696f6e">
# <label class="labe1" for="checkbox-1640973709575"></label>
# <span class="spanFilter" title="Últimas 48 horas">Últimas 48 horas</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f756c74696d612d73656d616e612d7075626c69636163696f6e">
# <label class="labe1" for="checkbox-1640973709576"></label>
# <span class="spanFilter" title="Última semana">Última semana</span>
# </li>
# ...
# <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjMxMTU4Ly0xMTY0NjAxMzg4LmpwZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=)">
# <div class="slider-cta-overlay-back"></div>
# <p>¿Te gusta?</p><button class="slider-main-cta btn-contact" data-adid="3036354" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">Contactar</button><button class="slider-secondary-cta" data-type="carousel">Ver en detalle</button>
# </div>
# </div><section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork"><meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjMxMTU4Ly0xMTY0NjAxMzg4LmpwZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" itemprop="url"/></section>
# <span class="slider-chevron left"></span><span class="slider-chevron right"></span>
# <div class="icons"> <span class="icon photo" data-total="4"><span class="current">1</span>/<span class="total">4</span></span> </div>
# </div>
# <div class="ad-data">
# <div class="data">
# <div class="price">				13,500 MX$			</div>
# <h2 class="title" itemprop="name"><a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/oficina-renta-costa-azul_3036354" itemprop="url">Oficina en Renta Acapulco De Juárez, Guerrero</a></h2>
# <p class="description" itemprop="description">Oficina en renta en el interior de la plaza pabellón costera, cuenta con vigilancia muy cerca de centros comerciales, cine...</p>
# <div class="adCharacteristics">
# <span class="numbers"> <span class="areaBuilt">50m2</span> </span>
# </div>
# </div>
# <div class="actions">
# <span class="like heart-login" data-adid="3036354" data-text="Favorito"></span>
# <div class="buttons"> <button class="btn-phone" data-adid="3036354" data-partner="Berenice Montejano" data-where="listing">Llamar</button>
# <button class="btn-contact" data-adid="3036354" data-where="listing">Contactar</button>
# </div>
# </div>
# </div>
# <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress"><meta content="MX" itemprop="addressCountry"/><meta content="Acapulco de Juárez" itemprop="addressLocality"/><meta content="Guerrero" itemprop="addressRegion"/><meta content="" itemprop="streetAddress"/></span>
# </li>
# <li class="ad" data-ev="0000343434363934392d31323031372d312d3239" id="4446949" itemscope="" itemtype="https://schema.org/Residence">
# <div class="ad-ph">
# <div class="slider-ad">
# <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" class="ill" data-src="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/><img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzkxNzY5NjcyNS5qcGVnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjoyNjYsImhlaWdodCI6MjEwLCJmaXQiOiJjb3ZlciIsIndpdGhvdXRFbmxhcmdlbWVudCI6dHJ1ZX19fQ==" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/><img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEwNTI1MTc3MTcuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
# <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19)">
# <div class="slider-cta-overlay-back"></div>
# <p>¿Te gusta?</p><button class="slider-main-cta btn-contact" data-adid="4446949" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">Contactar</button><button class="slider-secondary-cta" data-type="carousel">Ver en detalle</button>
# </div>
# </div><section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork"><meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" itemprop="url"/></section>
# <span class="slider-chevron left"></span><span class="slider-chevron right"></span>
# <div class="icons"> <span class="icon photo" data-total="3"><span class="current">1</span>/<span class="total">3</span></span> </div>
# </div>
# <div class="ad-data">
# <div class="data">
# <div class="price">				3,600 MX$			</div>
# <h2 class="title" itemprop="name"><a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/renta-oficina-hornos-insurgentes-acapulco-gro_4446949" itemprop="url">Oficina en Renta Hornos Insurgentes, Acapulco De Juárez</a></h2>
# <p class="description" itemprop="description">En renta oficina con excelente ubicación. La oficina cuenta con interfon, un baño para hombres y un baño para mujeres en ...</p>
# <div class="adCharacteristics">
# <span class="numbers"> <span class="areaBuilt">40m2</span> <span class="bathrooms">2<i class="icon-r-bathroom"></i></span> </span>
# </div>
# </div>
# <div class="actions">
# <span class="like heart-login" data-adid="4446949" data-text="Favorito"></span>
# <div class="buttons"> <button class="btn-phone" data-adid="4446949" data-partner="Century 21 Lacunza &amp; Asociados" data-where="listing">Llamar</button>
# <button class="btn-contact" data-adid="4446949" data-where="listing">Contactar</button>
# </div>
# </div>
# </div>
# <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress"><meta content="MX" itemprop="addressCountry"/><meta content="Hornos Insurgentes, Acapulco de Juárez" itemprop="addressLocality"/><meta content="Guerrero" itemprop="addressRegion"/><meta content="" itemprop="streetAddress"/></span>
# </li>
# <li class="ad" data-ev="0000343434363934372d31323031372d312d3330" id="4446947" itemscope="" itemtype="https://schema.org/Residence">
# <div class="ad-ph">
# <div class="slider-ad">
# <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" class="ill" data-src="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/><img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0yNzE2NzQ3NTMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
# <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=)">
# <div class="slider-cta-overlay-back"></div>
# <p>¿Te gusta?</p><button class="slider-main-cta btn-contact" data-adid="4446947" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">Contactar</button><button class="slider-secondary-cta" data-type="carousel">Ver en detalle</button>
# </div>
# </div><section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork"><meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" itemprop="url"/></section>
# <span class="slider-chevron left"></span><span class="slider-chevron right"></span>
# <div class="icons"> <span class="icon photo" data-total="2"><span class="current">1</span>/<span class="total">2</span></span> </div>
# </div>
# <div class="ad-data">
# <div class="data">
# <div class="price">				3,000 MX$			</div>
# <h2 class="title" itemprop="name"><a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/renta-oficina-hornos-insurgentes_4446947" itemprop="url">Oficina en Renta Hornos Insurgentes, Acapulco De Juárez</a></h2>
# <p class="description" itemprop="description">En renta oficina con excelente ubicación. La oficina cuenta con interfon, así como 2 baños , un baño para hombres y otro ...</p>
# <div class="adCharacteristics">
# <span class="numbers"> <span class="areaBuilt">39m2</span> <span class="bathrooms">2<i class="icon-r-bathroom"></i></span> </span>
# </div>
# </div>
# <div class="actions">
# <span class="like heart-login" data-adid="4446947" data-text="Favorito"></span>
# <div class="buttons"> <button class="btn-phone" data-adid="4446947" data-partner="Century 21 Lacunza &amp; Asociados" data-where="listing">Llamar</button>
# <button class="btn-contact" data-adid="4446947" data-where="listing">Contactar</button>
# </div>
# </div>
# </div>
# <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress"><meta content="MX" itemprop="addressCountry"/><meta content="Hornos Insurgentes, Acapulco de Juárez" itemprop="addressLocality"/><meta content="Guerrero" itemprop="addressRegion"/><meta content="" itemprop="streetAddress"/></span>
# </li>
# </ul>
# <ul aria-label="Pagination" class="pagination" data-tp="2" role="menubar"><li class="current"><span>1</span></li><li>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0/p_2" title="2">2
# </a>
# </li><li class="next">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f705f32" title="Siguiente">Siguiente</span>
# </li></ul>
# </article>
# </div>
# <section class="pop-up-contacto">
# </section>
# <footer>
# <div class="footer-content">
# <div class="footer-left">
# <ul>
# <li><a href="https://www.icasas.mx/noticias/">Blog</a></li>
# <li><a href="/quienesSomos">Quiénes somos</a></li>
# <li><a href="/politicaPrivacidad">Política de Privacidad</a></li>
# <li><a href="/politicaCookies">Política de Cookies</a></li>
# <li><a href="/contactanos">Contacta con icasas</a></li>
# </ul>
# <ul>
# <li><a class="publishYourProperty" href="/redirectCreateAdServlet">Publicar tu anuncio</a></li>
# <li><a href="/publicar/desarrolladora">Publicar como desarrolladora</a></li>
# <li><a href="/publicar/agencia">Publicar como profesional inmobiliario</a></li>
# <li><a href=""></a></li>
# <li><a href=""></a></li>
# </ul>
# </div>
# <div class="footer-right">
# <strong>icasas por todo el mundo</strong>
# <div class="footer-worldwide">
# <ul class="continent">
# <li><strong>América</strong></li>
# <li><a href="https://www.icasas.com.ar">Argentina</a></li>
# <li><a href="https://www.imocasa.com.br">Brasil</a></li>
# <li><a href="https://www.icasas.cl">icasas Chile</a></li>
# <li><a href="https://www.puntopropiedad.com">Colombia</a></li>
# </ul>
# <ul class="continent">
# <li><strong> </strong></li>
# <li><a href="https://www.icasas.co.cr/">Costa Rica</a></li>
# <li><a href="https://www.icasas.ec">Ecuador</a></li>
# <li><a href="https://www.icasas.mx">México</a></li>
# <li><a href="https://www.icasas.com.pa/">Panamá</a></li>
# <li><a href="https://www.laencontre.com.pe/">LaEncontre Perú</a></li>
# </ul>
# <ul class="continent">
# <li><strong>África</strong></li>
# <li><a href="http://www.persquare.co.za">Sudáfrica</a></li>
# </ul>
# <ul class="continent">
# <li><strong>Europa</strong></li>
# <li><a href="https://www.globaliza.com">España</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer-network">
# <div class="network-app">
# <p class="network-text">Descarga nuestra app</p>
# <a class="footer-app-icon google" href="https://play.google.com/store/apps/details?id=com.resem.app.mx"></a>
# </div>
# <div class="network-social">
# <p class="network-text">Entérate de las últimas novedades</p>
# <a class="footer-icon twitter" href="https://twitter.com/icasasmex" target="_blank"></a>
# <a class="footer-icon face" href="https://www.facebook.com/icasasmexico" target="_blank"></a>
# </div>
# </div>
# <div class="copyright">
# <span><strong>icasas</strong> Copyright 2021</span>
# </div>
# <script type="text/javascript">
# 		var g_client_id = '948427263315-8rtput7qre769n9nfd95r8skldfobek1.apps.googleusercontent.com';
# 		var cIso = 'MX';
# 	</script>
# </footer>
# <script defer="">
# 		var decimalSeparator='.';
# 		var groupingSeparator=',';
# 		var alertCreated = 'Alerta creada correctamente';var alertExistsText = 'Ya existe una alerta creada para esta búsqueda';
# 		var operationType='renta';
# 		var urlRequest ="";
#    		var callButtonText = "Llamar";
#    		var processingText = "Procesando...";
# 		var landingZoneSubUrl='zona';
# 		var language="es";
# 			urlRequest = '/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0';
# 		var pushNotificationsConfig = {
#   "enabled" : false,
#   "publicKey" : null
# }
#   	</script><script src="https://script.resemmedia.com/script/script/listing.min_v136.js" type="text/javascript"></script>
# <!--[if lt IE 9]>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/make_ie8_work.js"></script>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/modernizr.custom.84408.js"></script>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/selectivizr-min.js"></script>
# <![endif]-->
# <script defer="" type="text/javascript">
# analytics.setDimension('dimension1', 'anonimo');
# </script>
# <script defer="" type="text/javascript">
#
# 		analytics.setContent('contentGroup1', 'Guerrero-Acapulco de Juárez');
#
# 		analytics.setContent('contentGroup2', 'Zona');
#
# 	analytics.setContent('contentGroup3', 'oficina_renta');
#
# 	analytics.setContent('contentGroup4', 'listado_inmueble');
#
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-401688055"></script>
# <script>
#     var googleConversion = {
#         accountId: 'AW-401688055',
#         agencyConversionLabel: 'LsLFCJmP6f0BEPeLxb8B',
#         developerConversionLabel: 'wd1CCIfYts0CEPeLxb8B'
#     }
#
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', googleConversion.accountId);
#
#     function goog_report_conversion(type) {
#         if (type === undefined || type === "")  {
#             return;
#         }
#
#         var conversionLabel = googleConversion.agencyConversionLabel;
#         if(type === "developer") {
#             conversionLabel = googleConversion.developerConversionLabel;
#         }
#
#         let sendTo = googleConversion.accountId + "/" + conversionLabel;
#
#         gtag('event', 'conversion', {
#             'send_to': sendTo,
#             'event_callback': function() {}
#         });
#         return false;
#     }
# </script>
# <script defer="">
#
# 	analytics.contactRTB = true;
#
# 	analytics.send();
# </script>
# <iframe frameborder="0" height="1" scrolling="no" src="https://us.creativecdn.com/tags?id=pr_pHEG9OrA1ehGHoWzx1uu_listing_2405979,1851747,1851749,1851751,4149910" style="display: none;" width="1"></iframe>
# <div id="recaptchaPhone"></div>
# <input name="recaptchaSiteKey" type="hidden" value="6LcRZXoUAAAAAHseVHQSwR9Z7KSMT81ABP0yAeCO"/><link href="https://script.resemmedia.com/style/style/listing.min_v99.css" rel="stylesheet"/>
# <script type="text/javascript">
# 		$(document).ready(function(){
# 			if ($("input[id^='contact-phone'], input[id^='phone-']").length>0) {
# 				jsUtils.loadDialCodeCountries(cIso);
# 			}
# 			$("#g_prompt").css("left", $("header a.login").get(0).getBoundingClientRect().left - 330);
# 		});
# 	</script>
# </body>

# %%
print(b.p.parent.prettify())
# Out:
# <body>
#  <p>
#   &lt;![if !IE]&gt;&lt;![endif]&gt;
#  </p>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="es_MX" http-equiv="content-language"/>
#  <meta content="no-cache" http-equiv="Pragma"/>
#  <meta content="no-cache" http-equiv="Cache-Control"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-152x152_v2.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-144x144_v2.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-120x120_v2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-114x114_v2.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-72x72_v2.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-57x57_v2.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-32x32_v2.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-48x48_v2.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-64x64_v2.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link href="https://script.resemmedia.com/images/images/favicon/favicon-32x32_v2.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
#  <script>
#   var userLogged=false;
#  </script>
#  <title>
#   32 oficinas en renta en Acapulco de Juárez - icasas.mx
#  </title>
#  <meta content="index,follow" name="robots"/>
#  <meta content="comerciales oficinas-guerrero-acapulco-juarez" name="keywords"/>
#  <link href="https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" rel="canonical"/>
#  <link href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0/p_2" rel="next"/>
#  <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" name="title"/>
#  <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" name="description"/>
#  <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" property="og:title"/>
#  <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" property="og:description"/>
#  <meta content="https://script.resemmedia.com/images/images/logo-arrows_v1_big.png" property="og:image"/>
#  <meta content="https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" property="og:url"/>
#  <meta content="es_MX" property="og:locale"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="@icasasmex" name="twitter:site"/>
#  <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" name="twitter:title"/>
#  <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" name="twitter:description"/>
#  <meta content="https://script.resemmedia.com/images/images/logo-arrows_v1_big.png" name="twitter:image"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="app-id=com.resem.app.mx" name="google-play-app"/>
#  <link href="android-app://com.resem.app.mx/https/www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" rel="alternate"/>
#  <meta content="app-id=1093781012" name="apple-itunes-app"/>
#  <link href="https://fonts.gstatic.com" rel="preconnect"/>
#  <link href="https://script.resemmedia.com" rel="preconnect"/>
#  <link href="https://d2op7us8chplo5.cloudfront.net" rel="preconnect"/>
#  <link href="https://apis.google.com" rel="preconnect"/>
#  <link href="https://accounts.google.com" rel="preconnect"/>
#  <link href="https://www.google-analytics.com" rel="preconnect"/>
#  <link href="https://connect.facebook.net" rel="preconnect"/>
#  <link href="https://www.facebook.com" rel="preconnect"/>
#  <link href="https://cdn.ampproject.org" rel="preconnect"/>
#  <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#  <link href="https://www.gstatic.com" rel="preconnect"/>
#  <link href="https://www.googletagservices.com" rel="preconnect"/>
#  <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#  <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
#  <link href="https://adservice.google.com" rel="preconnect"/>
#  <link as="script" href="https://www.google-analytics.com/analytics.js" rel="preload"/>
#  <link as="script" href="https://www.googletagservices.com/tag/js/gpt.js" rel="preload"/>
#  <link as="script" href="https://script.resemmedia.com/script/script/listing.min_v136.js" rel="preload"/>
#  <link as="style" href="https://script.resemmedia.com/style/style/listing.min_v99.css" rel="preload"/>
#  <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600&amp;display=swap" rel="preload"/>
#  <link as="image" href="https://script.resemmedia.com/images/images/logo-icasas_v4.png" rel="preload"/>
#  <link as="image" href="https://script.resemmedia.com/images/images/loading-image-v2.svg" rel="preload"/>
#  <link as="image" href="https://script.resemmedia.com/images/images/web/no-image_v2.png" rel="preload"/>
#  <link as="image" href="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjUyMzEvLTI5OTg1NjE1OS5qcGciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjM1NCwiaGVpZ2h0IjoyNDAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" rel="preload"/>
#  <link as="image" href="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjE1NjA4ODkyMjYyODhfMTYzOTU4NDkzMi5qcGVnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjozNTAsImhlaWdodCI6MTAwLCJmaXQiOiJpbnNpZGUiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" rel="preload"/>
#  <style>
#   @import url(https://fonts.googleapis.com/css?family=Open+Sans:300,400,600&display=swap);@import url(https://script.resemmedia.com/fonts/fonts/font_icomoon_6rah64.css);body,select option,ul{padding:0;margin:0}#smartbanner,.filtro,body{overflow:hidden}.filtro .filtro-wrapper form,.slick-loading .slick-slide,.slick-loading .slick-track{visibility:hidden}html{height:100%}*,:after,:before{box-sizing:inherit}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,form,h1,h2,h3,h4,h5,h6,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline;box-sizing:border-box}#smartbanner,.slick-next:before,.slick-prev:before,body{-webkit-font-smoothing:antialiased}.ui-button-1,.ui-text-white-1{font-size:16px;font-weight:700}body{height:100vh;width:100%;position:relative;font-size:16px;color:#343434;overflow-y:scroll;font-family:"Open Sans",sans-serif,Arial,Helvetica}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:'';content:none}table{border-collapse:collapse;border-spacing:0}del{text-decoration:line-through}abbr[title],dfn[title]{border-bottom:1px dotted;cursor:help}article,aside,details,figcaption,figure,hgroup,main,menu,nav,section{display:block}button,input[type=text],input[type=email],input[type=tel],input[type=password],input[type=checkbox],input[type=number],input[type=submit],select{-webkit-appearance:none;-moz-appearance:none;appearance:none;border:0;outline:0;border-radius:0;-webkit-font-smoothing:antialiased}.uExternalRefresh,a,button,input[type=submit]{cursor:pointer}.ui-link-0{text-decoration:none}.ui-text-white-1{color:#fff;line-height:22px}.flex-center,.flex-center.ui-button-1{display:flex;align-items:center;justify-content:center}.has-error{border:2px solid #ec8f96!important;background-color:#fae3e5!important}.sprite{background-image:url(https://script.resemmedia.com/images/images/new_design/common/sprite_detail_v3.svg);color:transparent;display:block}.ui-button-1{width:100%;min-height:40px;background-color:#87c535;color:#fff;line-height:40px;text-align:center;display:block;border:0;border-radius:25px}.ui-button-1:hover{background-color:#ade05c}@-webkit-keyframes rotation{from{-webkit-transform:rotate(0)}to{-webkit-transform:rotate(359deg)}}.grecaptcha-badge{display:none}#smartbanner{position:absolute;left:0;top:-82px;width:100%;height:78px;z-index:9998;-webkit-text-size-adjust:none;background:#fff;border-bottom:1px solid #e0e0e0}#smartbanner .sb-container{margin:0 auto}#smartbanner .sb-container .sb-close{position:absolute;left:5px;top:5px;display:block;font-size:15px;text-align:center;text-decoration:none;text-shadow:none;border-radius:14px;-webkit-font-smoothing:subpixel-antialiased;border:0;width:17px;height:17px;line-height:17px;color:#343434;background:0 0;box-shadow:none;padding:25px 10px}#smartbanner .sb-container .sb-button,#smartbanner .sb-container .sb-info{position:absolute;text-shadow:0 1px 0 rgba(255,255,255,.8);font-weight:700}#smartbanner .sb-container .sb-icon{position:absolute;left:30px;top:10px;display:block;width:57px;height:57px;background-size:cover;border:none}#smartbanner .sb-container .sb-info{left:98px;top:18px;width:44%;font-size:11px;line-height:1.2em;color:#343434}#smartbanner .sb-container .sb-info strong{color:#4d75b7;display:block;font-size:13px;line-height:18px}#smartbanner .sb-container .sb-info>span{display:block}#smartbanner .sb-container .sb-button{border:none;min-width:12%;padding:1px;background:0 0;box-shadow:none;min-height:28px;right:20px;top:24px;height:24px;font-size:14px;line-height:24px;text-align:center;text-transform:uppercase;text-decoration:none}#smartbanner .sb-container .sb-button span{text-ali ...
#  </style>
#  <script defer="">
#   (function (d,b,l,c,k) {k = document.createElement(l);k.src = b;k.defer = true;d.getElementsByTagName(c)[0].appendChild(k);})(document, "https://www.googletagservices.com/tag/js/gpt.js", "script", "head");
# 	window.googletag = window.googletag || {cmd: []};
#  </script>
#  <script defer="" type="text/javascript">
#   var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# 	googletag.cmd.push(function() {
# 	//mapping size for responsive banners
# 	var mapping = googletag.sizeMapping().
# 		addSize([320, 400], [320, 90]).
# 		addSize([498, 400], [498, 90]).
# 		addSize([728, 400], [728, 90]).
# 		build();
#
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD3', [[728, 90],[840, 140],[860, 90],[570, 165],], 'list_third_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE3_SEARCH', [[300, 100],[250, 250],[250, 300],[300, 250],[300, 300],[300, 600],], 'list_third_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE1_SEARCH', [[250, 250],[300, 250],[300, 300],[300, 100],[250, 300],[300, 600],], 'list_first_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD1', [[960, 90],[728, 90],[860, 90],[970, 90],[498, 90],[860, 200],], 'list_first_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD2', [[498, 90],[970, 90],[728, 90],[960, 90],[860, 90],], 'list_second_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE4_SEARCH', [[300, 100],[300, 300],[300, 250],[250, 250],[250, 300],[300, 600],], 'list_fourth_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE2_SEARCH', [[300, 250],[300, 300],[250, 300],[300, 600],[250, 250],[300, 100],], 'list_second_filter').addService(googletag.pubads());
#
#     googletag.defineSlot('/1241729/TEXT_PRICE', [220, 30], 'div-gpt-ad-1469602311097-0').addService(googletag.pubads());
#     googletag.defineSlot('/1241729/TEXT_SERVICE_1', [220, 30], 'div-gpt-ad-1469602311097-1').addService(googletag.pubads());
#
# 	googletag.pubads().setTargeting("RESEM_OPERATION_TYPE",['renta']);
#
# 	googletag.pubads().setTargeting("RESEM_PROPERTY_TYPE",['oficina']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_1",['guerrero']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_2",['acapulco-juarez']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_0",['MX']);
#   	googletag.pubads().enableSingleRequest();
#   	googletag.pubads().collapseEmptyDivs();
#   	googletag.pubads().enableSyncRendering();
#  	googletag.enableServices();
# });
#  </script>
#  <script async="" type="text/javascript">
#   var isIE10 = false;
#     /*@cc_on
#         if (/^10/.test(@_jscript_version)) {
#             isIE10 = true;
#         }
#     @*/
#     if (isIE10) {
#         document.write("<link rel='stylesheet' href='/www/resem/new_design/listing/css/ie10.css'>");
#     }
#  </script>
#  <script async="">
#   var UA ="UA-42400835-1";
#
# 	var UAGlobal = "UA-42400835-14";
#
# 	var UAPlatform = "UA-158549811-8";
#
# 	var UACountryCode = "mx";
#
#
# 	var linkerDomains = ['puntopropiedad.com','icasas.cl','persquare.co.za','laencontre.com.pe','icasas.ec','icasas.com.pa','icasas.co.cr','imocasa.com.br','icasas.com.ar','globaliza.com'];
# 	var userId = "0";
#
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', UA, 'auto', {'allowLinker': true});
# 	ga('require', 'linker');
# 	ga('linker:autoLink', linkerDomains);
#
#
# 	ga('create', UAGlobal, 'auto', {'name':'global'});
# 	// Para lanzar el UA necesita tener un evento, puede que se lance en resem-analytics , usar pluggin Google Analytics Debugger
# 	if (typeof UAPlatform !== 'undefined') {
# 		ga('create', UAPlatform, 'auto', {'name':'platform'});
# 	}
#  </script>
#  <!-- Facebook Pixel Code -->
#  <script async="">
#   !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.defer=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 	fbq('init', '301253267239153');
# 	fbq('track', "PageView");
#
# 	fbq('init', '102954430074060');
# 	fbq('track', "PageView");
#  </script>
#  <noscript>
#   <img height="1" src="https://www.facebook.com/tr?id=301253267239153&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   <img height="1" src="https://www.facebook.com/tr?id=102954430074060&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#  </noscript>
#  <!-- End Facebook Pixel Code -->
#  <script>
#   var adas = "2f7777772f726573656d2f6e65775f64657369676e2f6c697374696e672f696e636c7564652f6c697374696e672d61642e6a7370";
#  </script>
#  <script>
#   const awp = 'listing';
#  </script>
#  <meta content="qndwlng7i8ppoj69vp0aem6hqouzsi" name="facebook-domain-verification"/>
#  <div class="menu__layer">
#  </div>
#  <div class="visible" id="avisoLegalCookies" onclick="ocultaAviso();">
#   icasas utiliza sus propias cookies y las de terceros para elaborar información estadística y así mostrarte publicidad relacionada con tus búsquedas. Al continuar navegando aceptas su uso. Puedes obtener más información aquí:
#   <a href="/politicaCookies" target="_blank">
#    Política de Cookies
#   </a>
#  </div>
#  <header>
#   <div class="js-menu maxWidth">
#    <div class="content-logo">
#     <div class="div-logo" itemscope="" itemtype="https://schema.org/Organization">
#      <a class="ui-link-0" href="/">
#       <img alt="Casas en venta y renta en México - icasas.mx" class="logo" itemprop="logo" src="https://script.resemmedia.com/images/images/logo-icasas_v4.png"/>
#       <meta content="https://www.icasas.mx/" itemprop="url"/>
#      </a>
#     </div>
#    </div>
#    <i class="icon-r-menu" id="openHeaderMenuMobile">
#    </i>
#    <ul class="items-list">
#     <li class="items-list__item">
#      <div class="js-dropdown modulo dropdown blue">
#       <button class="dropdown__btn-select" type="button">
#        <span class="text">
#         MX$
#        </span>
#       </button>
#       <ul class="dropdown__list alt-col js-nice">
#        <li class="dropdown__list__item currency-selector" data-id="" data-val="MXN">
#         MX$
#        </li>
#        <li class="dropdown__list__item currency-selector" data-id="" data-val="USD">
#         US$
#        </li>
#       </ul>
#      </div>
#     </li>
#     <li class="items-list__item">
#      <a class="icon login" href="#">
#       <span class="text ui-text-white-1" data-login="Login" data-my-account="Mi cuenta">
#        Login
#       </span>
#       <span class="icon-r-user login">
#       </span>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </header>
#  <div id="g_prompt" style="position:absolute; float:right; top:25px;">
#  </div>
#  <div class="menu">
#   <div class="menu__arrow">
#    <a class="ui-link-0" href="#">
#     <div>
#     </div>
#    </a>
#   </div>
#   <div class="menu__title">
#    <p class="ui-titular-1">
#     Iniciar sesión en Icasas México
#    </p>
#   </div>
#   <div class="menu__login">
#    <form action="/clientLoginServlet" class="login" method="post">
#     <div class="login__title ui-titular-2">
#      Cuenta de usuario
#     </div>
#     <div class="login__wrapper">
#      <p class="error display-none" id="loginFail">
#      </p>
#      <div class="input-form">
#       <input id="loginMail" name="email" placeholder="Email" type="email" value=""/>
#      </div>
#      <div class="input-form">
#       <input id="loginPassword" name="pwd" placeholder="Contraseña" type="password"/>
#      </div>
#      <div class="input-form">
#       <button class="ui-button-1" id="loginButton">
#        Ingresar
#       </button>
#      </div>
#      <!-- 				<div class="g-signin2" data-width="300" data-height="40" data-longtitle="true" data-theme="dark" data-onsuccess="gSignIn" async defer></div> -->
#      <div async="" defer="" id="myGoogleButton">
#      </div>
#      <div class="input-form text-center">
#       <a class="ui-text-grey-1" id="recoverPassword">
#        Recuperar contraseña
#       </a>
#      </div>
#     </div>
#    </form>
#   </div>
#   <div class="menu__registration">
#    <span class="ui-text-grey-1">
#     ¿Necesitas una cuenta?
#    </span>
#    <a class="ui-text-blue-1" data-where="listing" id="signUp">
#     Registrarse
#    </a>
#   </div>
#  </div>
#  <script>
#   var loginButtonTextLogin = 'Login';
# 		var loginButtonTextMyaccount = 'Mi cuenta';
#  </script>
#  <nav class="migas" itemscope="" itemtype="https://schema.org/BreadcrumbList">
#   <ul class="detail-pagination">
#    <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#     <a href="/" itemprop="item" title="icasas">
#      <span itemprop="name">
#       icasas
#      </span>
#      <i class="icon-r-chevron-right">
#      </i>
#     </a>
#     <meta content="1" itemprop="position"/>
#    </li>
#    <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#     <a href="/renta/comerciales-oficinas-3_14_0_0_0_0" itemprop="item" title="Oficinas en Renta">
#      <span itemprop="name">
#       Oficinas en Renta
#      </span>
#      <i class="icon-r-chevron-right">
#      </i>
#     </a>
#     <meta content="2" itemprop="position"/>
#    </li>
#    <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#     <a href="/renta/comerciales-oficinas-guerrero-3_14_12_0_0_0" itemprop="item" title="Guerrero">
#      <span itemprop="name">
#       Guerrero
#      </span>
#      <i class="icon-r-chevron-right">
#      </i>
#     </a>
#     <meta content="3" itemprop="position"/>
#    </li>
#    <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#     <a href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" itemprop="item" title="Acapulco de Juárez">
#      <span itemprop="name">
#       Acapulco de Juárez
#      </span>
#      <i class="icon-r-chevron-right">
#      </i>
#     </a>
#     <meta content="4" itemprop="position"/>
#    </li>
#   </ul>
#  </nav>
#  <div class="container-body listado">
#   <div class="aside">
#    <div class="alert floating-alert desktop">
#     <span class="text-hide">
#      Te avisamos de nuevos anuncios en tu mail:
#     </span>
#     <button class="create-alert-visitor" data-origin="LB" data-text="Crear alerta" data-text-small="Crear alerta">
#     </button>
#    </div>
#    <aside class="filtro">
#     <div class="cabeza">
#      <div class="filtrar">
#       FILTRA TU BÚSQUEDA
#       <i class="icon-r-cross cerrar-filtro">
#       </i>
#      </div>
#     </div>
#     <div class="filtro-wrapper">
#      <form class="ui-form-1">
#       <div class="regiones-wrapper mostrar provincia-dropw" data-ae="location">
#        <div class="regiones-pestana provincia-dropp">
#         <h3 class="title">
#          Barrio
#         </h3>
#         <i class="icon-r-chevron-down imgrotate">
#         </i>
#        </div>
#        <ul class="regiones-container">
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d61636170756c636f2d6a756172657a2d63656e74726f2d335f31345f31325f305f3336365f343431">
#          <label class="labe1" for="checkbox-7386">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-acapulco-juarez-centro-3_14_12_0_366_441" title="Acapulco de Juárez Centro">
#           Acapulco de Juárez Centro (2)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d636f6e646573612d335f31345f31325f305f3336365f32393738">
#          <label class="labe1" for="checkbox-12021">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-condesa-3_14_12_0_366_2978" title="Condesa">
#           Condesa (1)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d636f7374612d617a756c2d335f31345f31325f305f3336365f313030">
#          <label class="labe1" for="checkbox-12224">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-costa-azul-3_14_12_0_366_100" title="Costa Azul">
#           Costa Azul (2)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d686f726e6f732d696e73757267656e7465732d335f31345f31325f305f3336365f31373039">
#          <label class="labe1" for="checkbox-17139">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-hornos-insurgentes-3_14_12_0_366_1709" title="Hornos Insurgentes">
#           Hornos Insurgentes (3)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d6d6167616c6c616e65732d335f31345f31325f305f3336365f32393732">
#          <label class="labe1" for="checkbox-23745">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-magallanes-3_14_12_0_366_2972" title="Magallanes">
#           Magallanes (2)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d6e7565766f2d63617961636f2d335f31345f31325f305f3336365f3131333437">
#          <label class="labe1" for="checkbox-25643">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-nuevo-cayaco-3_14_12_0_366_11347" title="Nuevo Cayaco">
#           Nuevo Cayaco (2)
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="regiones-wrapper mostrar tipo-dropw" data-ae="type">
#        <div class="regiones-pestana tipo-dropp">
#         <h3 class="title">
#          Tipo de inmueble
#         </h3>
#         <i class="icon-r-chevron-down imgrotate">
#         </i>
#        </div>
#        <ul class="regiones-container">
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d656469666963696f732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31355f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-15">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-edificios-guerrero-acapulco-juarez-3_15_12_0_366_0" title="Edificio">
#           Edificios (7)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d677565727265726f2d61636170756c636f2d6a756172657a2d325f305f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-2">
#          </label>
#          <a class="linkFilter" href="/renta/habitacionales-guerrero-acapulco-juarez-2_0_12_0_366_0" title="Habitacional">
#           Habitacionales (1,939)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d696e6d7565626c65732d70726f6475637469766f732d757262616e6f732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31375f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-17">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-inmuebles-productivos-urbanos-guerrero-acapulco-juarez-3_17_12_0_366_0" title="Inmuebles productivos urbanos">
#           Inmuebles productivos urbanos (3)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6c6f63616c65732d636f6d65726369616c65732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31305f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-10">
#          </label>
#          <a class="linkFilter" href="/renta/comerciales-locales-comerciales-guerrero-acapulco-juarez-3_10_12_0_366_0" title="Local comercial">
#           Locales Comerciales (227)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f746965727261732d6c6f7465732d74657272656e6f732d677565727265726f2d61636170756c636f2d6a756172657a2d355f395f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-9">
#          </label>
#          <a class="linkFilter" href="/renta/tierras-lotes-terrenos-guerrero-acapulco-juarez-5_9_12_0_366_0" title="Lote de Terreno">
#           Lotes de Terrenos (37)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f696e647573747269616c65732d6e617665732d677565727265726f2d61636170756c636f2d6a756172657a2d345f32305f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-20">
#          </label>
#          <a class="linkFilter" href="/renta/industriales-naves-guerrero-acapulco-juarez-4_20_12_0_366_0" title="Nave">
#           Naves (28)
#          </a>
#         </li>
#         <li class="regiones iCheck">
#          <label class="labe1 checkSelected" for="checkbox-14">
#          </label>
#          <span class="spanFilter" title="Oficina">
#           Oficinas (32)
#          </span>
#         </li>
#        </ul>
#       </div>
#       <div class="regiones-wrapper mostrar sudtipo-dropw" data-ae="subtype">
#        <div class="regiones-pestana sudtipo-dropp">
#         <h3 class="title">
#          Otros tipos de propiedad
#         </h3>
#         <i class="icon-r-chevron-down imgrotate">
#         </i>
#        </div>
#        <ul class="regiones-container">
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d63617361732d677565727265726f2d61636170756c636f2d6a756172657a2d325f355f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-5">
#          </label>
#          <a class="linkFilter" href="/renta/habitacionales-casas-guerrero-acapulco-juarez-2_5_12_0_366_0" title="Casa">
#           Casas (687)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d63617361732d636f6e646f6d696e696f2d677565727265726f2d61636170756c636f2d6a756172657a2d325f375f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-7">
#          </label>
#          <a class="linkFilter" href="/renta/habitacionales-casas-condominio-guerrero-acapulco-juarez-2_7_12_0_366_0" title="Casa en condominio">
#           Casas condominio (57)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d646570617274616d656e746f732d677565727265726f2d61636170756c636f2d6a756172657a2d325f335f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-3">
#          </label>
#          <a class="linkFilter" href="/renta/habitacionales-departamentos-guerrero-acapulco-juarez-2_3_12_0_366_0" title="Departamento">
#           Departamentos (1,153)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d7175696e7461732d677565727265726f2d61636170756c636f2d6a756172657a2d325f345f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-4">
#          </label>
#          <a class="linkFilter" href="/renta/habitacionales-quintas-guerrero-acapulco-juarez-2_4_12_0_366_0" title="Quinta">
#           Quintas (13)
#          </a>
#         </li>
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d76696c6c61732d677565727265726f2d61636170756c636f2d6a756172657a2d325f315f31325f305f3336365f30">
#          <label class="labe1" for="checkbox-1">
#          </label>
#          <a class="linkFilter" href="/renta/habitacionales-villas-guerrero-acapulco-juarez-2_1_12_0_366_0" title="Villa">
#           Villas (29)
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="regiones-wrapper mostrar confoto" data-ae="other">
#        <ul class="regiones-container">
#         <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f666f746f73">
#          <label class="labe1" for="checkbox-1640973709568">
#          </label>
#          <span class="spanFilter" title="Fotos">
#           Fotos
#          </span>
#         </li>
#        </ul>
#       </div>
#       <div class="precios-wrapper" id="precios-wrapper">
#        <div class="regiones-wrapper preciomax" data-ae="priceMin">
#         <div class="regiones-pestana preciomax-dropp">
#          <h3 class="title">
#           Precio Mín.
#          </h3>
#         </div>
#         <input class="buscador buscadorprice integer-input" id="priceMin" name="priceMin" placeholder="" type="search" value=""/>
#         <div class="filter-dropdown" data-where="price-min">
#          <ul>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d70726563696f" title="200">
#             200
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d70726563696f" title="500">
#             500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d70726563696f" title="1,000">
#             1,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313530302d70726563696f" title="1,500">
#             1,500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f323030302d70726563696f" title="2,000">
#             2,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f323530302d70726563696f" title="2,500">
#             2,500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f333030302d70726563696f" title="3,000">
#             3,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f333530302d70726563696f" title="3,500">
#             3,500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f343030302d70726563696f" title="4,000">
#             4,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f353030302d70726563696f" title="5,000">
#             5,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f373030302d70726563696f" title="7,000">
#             7,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31303030302d70726563696f" title="10,000">
#             10,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31323030302d70726563696f" title="12,000">
#             12,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31353030302d70726563696f" title="15,000">
#             15,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31373030302d70726563696f" title="17,000">
#             17,000
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="regiones-wrapper preciomax" data-ae="priceMax">
#         <div class="regiones-pestana preciomax-dropp">
#          <h3 class="title">
#           Precio Máx.
#          </h3>
#         </div>
#         <input class="buscador buscadorprice integer-input" id="priceMax" name="priceMax" placeholder="" type="search" value=""/>
#         <div class="filter-dropdown" data-where="price-max">
#          <ul>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d3230302d70726563696f" title="200">
#             200
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d3530302d70726563696f" title="500">
#             500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d313030302d70726563696f" title="1,000">
#             1,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d313530302d70726563696f" title="1,500">
#             1,500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d323030302d70726563696f" title="2,000">
#             2,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d323530302d70726563696f" title="2,500">
#             2,500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d333030302d70726563696f" title="3,000">
#             3,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d333530302d70726563696f" title="3,500">
#             3,500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d343030302d70726563696f" title="4,000">
#             4,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d353030302d70726563696f" title="5,000">
#             5,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d373030302d70726563696f" title="7,000">
#             7,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31303030302d70726563696f" title="10,000">
#             10,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31323030302d70726563696f" title="12,000">
#             12,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31353030302d70726563696f" title="15,000">
#             15,000
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31373030302d70726563696f" title="17,000">
#             17,000
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="precios-wrapper" id="surface-wrapper">
#        <div class="regiones-wrapper preciomax" data-ae="surfaceMin">
#         <div class="regiones-pestana preciomax-dropp">
#          <h3 class="title">
#           Área Min.
#          </h3>
#         </div>
#         <input class="buscador buscadorprice integer-input" id="surfaceMin" name="surfaceMin" placeholder="" type="search" value=""/>
#         <div class="filter-dropdown" data-where="surface-min">
#          <ul>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f35302d6d32" title="50">
#             50
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3130302d6d32" title="100">
#             100
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3135302d6d32" title="150">
#             150
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d6d32" title="200">
#             200
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3235302d6d32" title="250">
#             250
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3330302d6d32" title="300">
#             300
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d6d32" title="500">
#             500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d6d32" title="1,000">
#             1,000
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="regiones-wrapper preciomax" data-ae="surfaceMax">
#         <div class="regiones-pestana preciomax-dropp">
#          <h3 class="title">
#           Área Máx.
#          </h3>
#         </div>
#         <input class="buscador buscadorprice integer-input" id="surfaceMax" name="surfaceMax" placeholder="" type="search" value=""/>
#         <div class="filter-dropdown" data-where="surface-max">
#          <ul>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f35302d6d32" title="50">
#             50
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3130302d6d32" title="100">
#             100
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3135302d6d32" title="150">
#             150
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d6d32" title="200">
#             200
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3235302d6d32" title="250">
#             250
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3330302d6d32" title="300">
#             300
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d6d32" title="500">
#             500
#            </span>
#           </li>
#           <li class="dropdown-price">
#            <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d6d32" title="1,000">
#             1,000
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="prestas-flex">
#        <div class="regiones-wrapper presta-dropw mostrar" data-ae="rooms">
#         <div class="regiones-pestana presta-dropp">
# ...
#      <div class="ad-ph">
#       <div class="slider-ad">
#        <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" class="ill" data-src="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
#        <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzkxNzY5NjcyNS5qcGVnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjoyNjYsImhlaWdodCI6MjEwLCJmaXQiOiJjb3ZlciIsIndpdGhvdXRFbmxhcmdlbWVudCI6dHJ1ZX19fQ==" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
#        <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEwNTI1MTc3MTcuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
#        <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19)">
#         <div class="slider-cta-overlay-back">
#         </div>
#         <p>
#          ¿Te gusta?
#         </p>
#         <button class="slider-main-cta btn-contact" data-adid="4446949" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">
#          Contactar
#         </button>
#         <button class="slider-secondary-cta" data-type="carousel">
#          Ver en detalle
#         </button>
#        </div>
#       </div>
#       <section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork">
#        <meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" itemprop="url"/>
#       </section>
#       <span class="slider-chevron left">
#       </span>
#       <span class="slider-chevron right">
#       </span>
#       <div class="icons">
#        <span class="icon photo" data-total="3">
#         <span class="current">
#          1
#         </span>
#         /
#         <span class="total">
#          3
#         </span>
#        </span>
#       </div>
#      </div>
#      <div class="ad-data">
#       <div class="data">
#        <div class="price">
#         3,600 MX$
#        </div>
#        <h2 class="title" itemprop="name">
#         <a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/renta-oficina-hornos-insurgentes-acapulco-gro_4446949" itemprop="url">
#          Oficina en Renta Hornos Insurgentes, Acapulco De Juárez
#         </a>
#        </h2>
#        <p class="description" itemprop="description">
#         En renta oficina con excelente ubicación. La oficina cuenta con interfon, un baño para hombres y un baño para mujeres en ...
#        </p>
#        <div class="adCharacteristics">
#         <span class="numbers">
#          <span class="areaBuilt">
#           40m2
#          </span>
#          <span class="bathrooms">
#           2
#           <i class="icon-r-bathroom">
#           </i>
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="actions">
#        <span class="like heart-login" data-adid="4446949" data-text="Favorito">
#        </span>
#        <div class="buttons">
#         <button class="btn-phone" data-adid="4446949" data-partner="Century 21 Lacunza &amp; Asociados" data-where="listing">
#          Llamar
#         </button>
#         <button class="btn-contact" data-adid="4446949" data-where="listing">
#          Contactar
#         </button>
#        </div>
#       </div>
#      </div>
#      <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress">
#       <meta content="MX" itemprop="addressCountry"/>
#       <meta content="Hornos Insurgentes, Acapulco de Juárez" itemprop="addressLocality"/>
#       <meta content="Guerrero" itemprop="addressRegion"/>
#       <meta content="" itemprop="streetAddress"/>
#      </span>
#     </li>
#     <li class="ad" data-ev="0000343434363934372d31323031372d312d3330" id="4446947" itemscope="" itemtype="https://schema.org/Residence">
#      <div class="ad-ph">
#       <div class="slider-ad">
#        <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" class="ill" data-src="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
#        <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0yNzE2NzQ3NTMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
#        <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=)">
#         <div class="slider-cta-overlay-back">
#         </div>
#         <p>
#          ¿Te gusta?
#         </p>
#         <button class="slider-main-cta btn-contact" data-adid="4446947" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">
#          Contactar
#         </button>
#         <button class="slider-secondary-cta" data-type="carousel">
#          Ver en detalle
#         </button>
#        </div>
#       </div>
#       <section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork">
#        <meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" itemprop="url"/>
#       </section>
#       <span class="slider-chevron left">
#       </span>
#       <span class="slider-chevron right">
#       </span>
#       <div class="icons">
#        <span class="icon photo" data-total="2">
#         <span class="current">
#          1
#         </span>
#         /
#         <span class="total">
#          2
#         </span>
#        </span>
#       </div>
#      </div>
#      <div class="ad-data">
#       <div class="data">
#        <div class="price">
#         3,000 MX$
#        </div>
#        <h2 class="title" itemprop="name">
#         <a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/renta-oficina-hornos-insurgentes_4446947" itemprop="url">
#          Oficina en Renta Hornos Insurgentes, Acapulco De Juárez
#         </a>
#        </h2>
#        <p class="description" itemprop="description">
#         En renta oficina con excelente ubicación. La oficina cuenta con interfon, así como 2 baños , un baño para hombres y otro ...
#        </p>
#        <div class="adCharacteristics">
#         <span class="numbers">
#          <span class="areaBuilt">
#           39m2
#          </span>
#          <span class="bathrooms">
#           2
#           <i class="icon-r-bathroom">
#           </i>
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="actions">
#        <span class="like heart-login" data-adid="4446947" data-text="Favorito">
#        </span>
#        <div class="buttons">
#         <button class="btn-phone" data-adid="4446947" data-partner="Century 21 Lacunza &amp; Asociados" data-where="listing">
#          Llamar
#         </button>
#         <button class="btn-contact" data-adid="4446947" data-where="listing">
#          Contactar
#         </button>
#        </div>
#       </div>
#      </div>
#      <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress">
#       <meta content="MX" itemprop="addressCountry"/>
#       <meta content="Hornos Insurgentes, Acapulco de Juárez" itemprop="addressLocality"/>
#       <meta content="Guerrero" itemprop="addressRegion"/>
#       <meta content="" itemprop="streetAddress"/>
#      </span>
#     </li>
#    </ul>
#    <ul aria-label="Pagination" class="pagination" data-tp="2" role="menubar">
#     <li class="current">
#      <span>
#       1
#      </span>
#     </li>
#     <li>
#      <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0/p_2" title="2">
#       2
#      </a>
#     </li>
#     <li class="next">
#      <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f705f32" title="Siguiente">
#       Siguiente
#      </span>
#     </li>
#    </ul>
#   </article>
#  </div>
#  <section class="pop-up-contacto">
#  </section>
#  <footer>
#   <div class="footer-content">
#    <div class="footer-left">
#     <ul>
#      <li>
#       <a href="https://www.icasas.mx/noticias/">
#        Blog
#       </a>
#      </li>
#      <li>
#       <a href="/quienesSomos">
#        Quiénes somos
#       </a>
#      </li>
#      <li>
#       <a href="/politicaPrivacidad">
#        Política de Privacidad
#       </a>
#      </li>
#      <li>
#       <a href="/politicaCookies">
#        Política de Cookies
#       </a>
#      </li>
#      <li>
#       <a href="/contactanos">
#        Contacta con icasas
#       </a>
#      </li>
#     </ul>
#     <ul>
#      <li>
#       <a class="publishYourProperty" href="/redirectCreateAdServlet">
#        Publicar tu anuncio
#       </a>
#      </li>
#      <li>
#       <a href="/publicar/desarrolladora">
#        Publicar como desarrolladora
#       </a>
#      </li>
#      <li>
#       <a href="/publicar/agencia">
#        Publicar como profesional inmobiliario
#       </a>
#      </li>
#      <li>
#       <a href="">
#       </a>
#      </li>
#      <li>
#       <a href="">
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="footer-right">
#     <strong>
#      icasas por todo el mundo
#     </strong>
#     <div class="footer-worldwide">
#      <ul class="continent">
#       <li>
#        <strong>
#         América
#        </strong>
#       </li>
#       <li>
#        <a href="https://www.icasas.com.ar">
#         Argentina
#        </a>
#       </li>
#       <li>
#        <a href="https://www.imocasa.com.br">
#         Brasil
#        </a>
#       </li>
#       <li>
#        <a href="https://www.icasas.cl">
#         icasas Chile
#        </a>
#       </li>
#       <li>
#        <a href="https://www.puntopropiedad.com">
#         Colombia
#        </a>
#       </li>
#      </ul>
#      <ul class="continent">
#       <li>
#        <strong>
#        </strong>
#       </li>
#       <li>
#        <a href="https://www.icasas.co.cr/">
#         Costa Rica
#        </a>
#       </li>
#       <li>
#        <a href="https://www.icasas.ec">
#         Ecuador
#        </a>
#       </li>
#       <li>
#        <a href="https://www.icasas.mx">
#         México
#        </a>
#       </li>
#       <li>
#        <a href="https://www.icasas.com.pa/">
#         Panamá
#        </a>
#       </li>
#       <li>
#        <a href="https://www.laencontre.com.pe/">
#         LaEncontre Perú
#        </a>
#       </li>
#      </ul>
#      <ul class="continent">
#       <li>
#        <strong>
#         África
#        </strong>
#       </li>
#       <li>
#        <a href="http://www.persquare.co.za">
#         Sudáfrica
#        </a>
#       </li>
#      </ul>
#      <ul class="continent">
#       <li>
#        <strong>
#         Europa
#        </strong>
#       </li>
#       <li>
#        <a href="https://www.globaliza.com">
#         España
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="footer-network">
#    <div class="network-app">
#     <p class="network-text">
#      Descarga nuestra app
#     </p>
#     <a class="footer-app-icon google" href="https://play.google.com/store/apps/details?id=com.resem.app.mx">
#     </a>
#    </div>
#    <div class="network-social">
#     <p class="network-text">
#      Entérate de las últimas novedades
#     </p>
#     <a class="footer-icon twitter" href="https://twitter.com/icasasmex" target="_blank">
#     </a>
#     <a class="footer-icon face" href="https://www.facebook.com/icasasmexico" target="_blank">
#     </a>
#    </div>
#   </div>
#   <div class="copyright">
#    <span>
#     <strong>
#      icasas
#     </strong>
#     Copyright 2021
#    </span>
#   </div>
#   <script type="text/javascript">
#    var g_client_id = '948427263315-8rtput7qre769n9nfd95r8skldfobek1.apps.googleusercontent.com';
# 		var cIso = 'MX';
#   </script>
#  </footer>
#  <script defer="">
#   var decimalSeparator='.';
# 		var groupingSeparator=',';
# 		var alertCreated = 'Alerta creada correctamente';var alertExistsText = 'Ya existe una alerta creada para esta búsqueda';
# 		var operationType='renta';
# 		var urlRequest ="";
#    		var callButtonText = "Llamar";
#    		var processingText = "Procesando...";
# 		var landingZoneSubUrl='zona';
# 		var language="es";
# 			urlRequest = '/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0';
# 		var pushNotificationsConfig = {
#   "enabled" : false,
#   "publicKey" : null
# }
#  </script>
#  <script src="https://script.resemmedia.com/script/script/listing.min_v136.js" type="text/javascript">
#  </script>
#  <!--[if lt IE 9]>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/make_ie8_work.js"></script>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/modernizr.custom.84408.js"></script>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/selectivizr-min.js"></script>
# <![endif]-->
#  <script defer="" type="text/javascript">
#   analytics.setDimension('dimension1', 'anonimo');
#  </script>
#  <script defer="" type="text/javascript">
#   analytics.setContent('contentGroup1', 'Guerrero-Acapulco de Juárez');
#
# 		analytics.setContent('contentGroup2', 'Zona');
#
# 	analytics.setContent('contentGroup3', 'oficina_renta');
#
# 	analytics.setContent('contentGroup4', 'listado_inmueble');
#  </script>
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-401688055">
#  </script>
#  <script>
#   var googleConversion = {
#         accountId: 'AW-401688055',
#         agencyConversionLabel: 'LsLFCJmP6f0BEPeLxb8B',
#         developerConversionLabel: 'wd1CCIfYts0CEPeLxb8B'
#     }
#
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', googleConversion.accountId);
#
#     function goog_report_conversion(type) {
#         if (type === undefined || type === "")  {
#             return;
#         }
#
#         var conversionLabel = googleConversion.agencyConversionLabel;
#         if(type === "developer") {
#             conversionLabel = googleConversion.developerConversionLabel;
#         }
#
#         let sendTo = googleConversion.accountId + "/" + conversionLabel;
#
#         gtag('event', 'conversion', {
#             'send_to': sendTo,
#             'event_callback': function() {}
#         });
#         return false;
#     }
#  </script>
#  <script defer="">
#   analytics.contactRTB = true;
#
# 	analytics.send();
#  </script>
#  <iframe frameborder="0" height="1" scrolling="no" src="https://us.creativecdn.com/tags?id=pr_pHEG9OrA1ehGHoWzx1uu_listing_2405979,1851747,1851749,1851751,4149910" style="display: none;" width="1">
#  </iframe>
#  <div id="recaptchaPhone">
#  </div>
#  <input name="recaptchaSiteKey" type="hidden" value="6LcRZXoUAAAAAHseVHQSwR9Z7KSMT81ABP0yAeCO"/>
#  <link href="https://script.resemmedia.com/style/style/listing.min_v99.css" rel="stylesheet"/>
#  <script type="text/javascript">
#   $(document).ready(function(){
# 			if ($("input[id^='contact-phone'], input[id^='phone-']").length>0) {
# 				jsUtils.loadDialCodeCountries(cIso);
# 			}
# 			$("#g_prompt").css("left", $("header a.login").get(0).getBoundingClientRect().left - 330);
# 		});
#  </script>
# </body>

# %%
print(b.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <!--[if gte IE 6]><html class="ie" lang="es_MX"><![endif]--><html><body><p>&lt;![if !IE]&gt;&lt;![endif]&gt;</p><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="es_MX" http-equiv="content-language"/><meta content="no-cache" http-equiv="Pragma"/><meta content="no-cache" http-equiv="Cache-Control"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-152x152_v2.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-144x144_v2.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-120x120_v2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-114x114_v2.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-72x72_v2.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-57x57_v2.png" rel="apple-touch-icon-precomposed" sizes="57x57"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-32x32_v2.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-48x48_v2.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-64x64_v2.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://script.resemmedia.com/images/images/favicon/favicon-32x32_v2.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
# <script>var userLogged=false;</script>
# <title>32 oficinas en renta en Acapulco de Juárez - icasas.mx</title>
# <meta content="index,follow" name="robots"/>
# <meta content="comerciales oficinas-guerrero-acapulco-juarez" name="keywords"/>
# <link href="https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" rel="canonical"/>
# <link href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0/p_2" rel="next"/>
# <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" name="title"/>
# <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" name="description"/>
# <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" property="og:title"/>
# <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" property="og:description"/>
# <meta content="https://script.resemmedia.com/images/images/logo-arrows_v1_big.png" property="og:image"/>
# <meta content="https://www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" property="og:url"/>
# <meta content="es_MX" property="og:locale"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@icasasmex" name="twitter:site"/>
# <meta content="32 oficinas en renta en Acapulco de Juárez - icasas.mx" name="twitter:title"/>
# <meta content="Encuentra la mejor oferta de oficinas en renta en Acapulco de Juárez. Actualmente tenemos disponibles 32 oficinas en Acapulco de Juárez" name="twitter:description"/>
# <meta content="https://script.resemmedia.com/images/images/logo-arrows_v1_big.png" name="twitter:image"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="app-id=com.resem.app.mx" name="google-play-app"/>
# <link href="android-app://com.resem.app.mx/https/www.icasas.mx/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" rel="alternate"/>
# <meta content="app-id=1093781012" name="apple-itunes-app"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://script.resemmedia.com" rel="preconnect"/>
# <link href="https://d2op7us8chplo5.cloudfront.net" rel="preconnect"/>
# <link href="https://apis.google.com" rel="preconnect"/>
# <link href="https://accounts.google.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://connect.facebook.net" rel="preconnect"/>
# <link href="https://www.facebook.com" rel="preconnect"/>
# <link href="https://cdn.ampproject.org" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://www.gstatic.com" rel="preconnect"/>
# <link href="https://www.googletagservices.com" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
# <link href="https://adservice.google.com" rel="preconnect"/>
# <link as="script" href="https://www.google-analytics.com/analytics.js" rel="preload"/>
# <link as="script" href="https://www.googletagservices.com/tag/js/gpt.js" rel="preload"/>
# <link as="script" href="https://script.resemmedia.com/script/script/listing.min_v136.js" rel="preload"/>
# <link as="style" href="https://script.resemmedia.com/style/style/listing.min_v99.css" rel="preload"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600&amp;display=swap" rel="preload"/>
# <link as="image" href="https://script.resemmedia.com/images/images/logo-icasas_v4.png" rel="preload"/>
# <link as="image" href="https://script.resemmedia.com/images/images/loading-image-v2.svg" rel="preload"/>
# <link as="image" href="https://script.resemmedia.com/images/images/web/no-image_v2.png" rel="preload"/>
# <link as="image" href="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjUyMzEvLTI5OTg1NjE1OS5qcGciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjM1NCwiaGVpZ2h0IjoyNDAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" rel="preload"/>
# <link as="image" href="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjE1NjA4ODkyMjYyODhfMTYzOTU4NDkzMi5qcGVnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjozNTAsImhlaWdodCI6MTAwLCJmaXQiOiJpbnNpZGUiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" rel="preload"/>
# <style>
#     @import url(https://fonts.googleapis.com/css?family=Open+Sans:300,400,600&display=swap);@import url(https://script.resemmedia.com/fonts/fonts/font_icomoon_6rah64.css);body,select option,ul{padding:0;margin:0}#smartbanner,.filtro,body{overflow:hidden}.filtro .filtro-wrapper form,.slick-loading .slick-slide,.slick-loading .slick-track{visibility:hidden}html{height:100%}*,:after,:before{box-sizing:inherit}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,form,h1,h2,h3,h4,h5,h6,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font:inherit;vertical-align:baseline;box-sizing:border-box}#smartbanner,.slick-next:before,.slick-prev:before,body{-webkit-font-smoothing:antialiased}.ui-button-1,.ui-text-white-1{font-size:16px;font-weight:700}body{height:100vh;width:100%;position:relative;font-size:16px;color:#343434;overflow-y:scroll;font-family:"Open Sans",sans-serif,Arial,Helvetica}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:'';content:none}table{border-collapse:collapse;border-spacing:0}del{text-decoration:line-through}abbr[title],dfn[title]{border-bottom:1px dotted;cursor:help}article,aside,details,figcaption,figure,hgroup,main,menu,nav,section{display:block}button,input[type=text],input[type=email],input[type=tel],input[type=password],input[type=checkbox],input[type=number],input[type=submit],select{-webkit-appearance:none;-moz-appearance:none;appearance:none;border:0;outline:0;border-radius:0;-webkit-font-smoothing:antialiased}.uExternalRefresh,a,button,input[type=submit]{cursor:pointer}.ui-link-0{text-decoration:none}.ui-text-white-1{color:#fff;line-height:22px}.flex-center,.flex-center.ui-button-1{display:flex;align-items:center;justify-content:center}.has-error{border:2px solid #ec8f96!important;background-color:#fae3e5!important}.sprite{background-image:url(https://script.resemmedia.com/images/images/new_design/common/sprite_detail_v3.svg);color:transparent;display:block}.ui-button-1{width:100%;min-height:40px;background-color:#87c535;color:#fff;line-height:40px;text-align:center;display:block;border:0;border-radius:25px}.ui-button-1:hover{background-color:#ade05c}@-webkit-keyframes rotation{from{-webkit-transform:rotate(0)}to{-webkit-transform:rotate(359deg)}}.grecaptcha-badge{display:none}#smartbanner{position:absolute;left:0;top:-82px;width:100%;height:78px;z-index:9998;-webkit-text-size-adjust:none;background:#fff;border-bottom:1px solid #e0e0e0}#smartbanner .sb-container{margin:0 auto}#smartbanner .sb-container .sb-close{position:absolute;left:5px;top:5px;display:block;font-size:15px;text-align:center;text-decoration:none;text-shadow:none;border-radius:14px;-webkit-font-smoothing:subpixel-antialiased;border:0;width:17px;height:17px;line-height:17px;color:#343434;background:0 0;box-shadow:none;padding:25px 10px}#smartbanner .sb-container .sb-button,#smartbanner .sb-container .sb-info{position:absolute;text-shadow:0 1px 0 rgba(255,255,255,.8);font-weight:700}#smartbanner .sb-container .sb-icon{position:absolute;left:30px;top:10px;display:block;width:57px;height:57px;background-size:cover;border:none}#smartbanner .sb-container .sb-info{left:98px;top:18px;width:44%;font-size:11px;line-height:1.2em;color:#343434}#smartbanner .sb-container .sb-info strong{color:#4d75b7;display:block;font-size:13px;line-height:18px}#smartbanner .sb-container .sb-info>span{display:block}#smartbanner .sb-container .sb-button{border:none;min-width:12%;padding:1px;background:0 0;box-shadow:none;min-height:28px;right:20px;top:24px;height:24px;font-size:14px;line-height:24px;text-align:center;text-transform:uppercase;text-decoration:none}#smartbanner .sb-container .sb-button span{text-a ...
# <script defer="">
# 	(function (d,b,l,c,k) {k = document.createElement(l);k.src = b;k.defer = true;d.getElementsByTagName(c)[0].appendChild(k);})(document, "https://www.googletagservices.com/tag/js/gpt.js", "script", "head");
# 	window.googletag = window.googletag || {cmd: []};
# </script>
# <script defer="" type="text/javascript">
# 	var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# 	googletag.cmd.push(function() {
# 	//mapping size for responsive banners
# 	var mapping = googletag.sizeMapping().
# 		addSize([320, 400], [320, 90]).
# 		addSize([498, 400], [498, 90]).
# 		addSize([728, 400], [728, 90]).
# 		build();
#
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD3', [[860, 90],[570, 165],[728, 90],[840, 140],], 'list_third_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE3_SEARCH', [[300, 600],[250, 300],[300, 250],[300, 100],[250, 250],[300, 300],], 'list_third_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE1_SEARCH', [[300, 600],[250, 300],[300, 100],[300, 250],[300, 300],[250, 250],], 'list_first_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD1', [[728, 90],[970, 90],[860, 200],[498, 90],[860, 90],[960, 90],], 'list_first_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/HORIZONTAL_LEADERBOARD2', [[960, 90],[860, 90],[728, 90],[498, 90],[970, 90],], 'list_second_horizontal').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE4_SEARCH', [[250, 250],[300, 600],[300, 250],[250, 300],[300, 300],[300, 100],], 'list_fourth_filter').addService(googletag.pubads());
# 			googletag.defineSlot('/1241729/SQUARE2_SEARCH', [[250, 250],[300, 300],[250, 300],[300, 600],[300, 250],[300, 100],], 'list_second_filter').addService(googletag.pubads());
#
#     googletag.defineSlot('/1241729/TEXT_PRICE', [220, 30], 'div-gpt-ad-1469602311097-0').addService(googletag.pubads());
#     googletag.defineSlot('/1241729/TEXT_SERVICE_1', [220, 30], 'div-gpt-ad-1469602311097-1').addService(googletag.pubads());
#
# 	googletag.pubads().setTargeting("RESEM_OPERATION_TYPE",['renta']);
#
# 	googletag.pubads().setTargeting("RESEM_PROPERTY_TYPE",['oficina']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_1",['guerrero']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_2",['acapulco-juarez']);
#
# 	googletag.pubads().setTargeting("RESEM_ZONE_0",['MX']);
#   	googletag.pubads().enableSingleRequest();
#   	googletag.pubads().collapseEmptyDivs();
#   	googletag.pubads().enableSyncRendering();
#  	googletag.enableServices();
# });
# 	</script><script async="" type="text/javascript">
#     var isIE10 = false;
#     /*@cc_on
#         if (/^10/.test(@_jscript_version)) {
#             isIE10 = true;
#         }
#     @*/
#     if (isIE10) {
#         document.write("<link rel='stylesheet' href='/www/resem/new_design/listing/css/ie10.css'>");
#     }
# </script>
# <script async="">
# 	var UA ="UA-42400835-1";
#
# 	var UAGlobal = "UA-42400835-14";
#
# 	var UAPlatform = "UA-158549811-8";
#
# 	var UACountryCode = "mx";
#
#
# 	var linkerDomains = ['puntopropiedad.com','icasas.cl','persquare.co.za','laencontre.com.pe','icasas.ec','icasas.com.pa','icasas.co.cr','imocasa.com.br','icasas.com.ar','globaliza.com'];
# 	var userId = "0";
#
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', UA, 'auto', {'allowLinker': true});
# 	ga('require', 'linker');
# 	ga('linker:autoLink', linkerDomains);
#
#
# 	ga('create', UAGlobal, 'auto', {'name':'global'});
# 	// Para lanzar el UA necesita tener un evento, puede que se lance en resem-analytics , usar pluggin Google Analytics Debugger
# 	if (typeof UAPlatform !== 'undefined') {
# 		ga('create', UAPlatform, 'auto', {'name':'platform'});
# 	}
# </script>
# <!-- Facebook Pixel Code -->
# <script async="">
# 	!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.defer=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 	fbq('init', '301253267239153');
# 	fbq('track', "PageView");
#
# 	fbq('init', '102954430074060');
# 	fbq('track', "PageView");
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=301253267239153&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/><img height="1" src="https://www.facebook.com/tr?id=102954430074060&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code --><script>
#     var adas = "2f7777772f726573656d2f6e65775f64657369676e2f6c697374696e672f696e636c7564652f6c697374696e672d61642e6a7370";
# </script>
# <script>const awp = 'listing';</script>
# <meta content="qndwlng7i8ppoj69vp0aem6hqouzsi" name="facebook-domain-verification"/>
# <div class="menu__layer"></div><div class="visible" id="avisoLegalCookies" onclick="ocultaAviso();">
# 	icasas utiliza sus propias cookies y las de terceros para elaborar información estadística y así mostrarte publicidad relacionada con tus búsquedas. Al continuar navegando aceptas su uso. Puedes obtener más información aquí:
# 	<a href="/politicaCookies" target="_blank">Política de Cookies</a>
# </div>
# <header><div class="js-menu maxWidth">
# <div class="content-logo">
# <div class="div-logo" itemscope="" itemtype="https://schema.org/Organization">
# <a class="ui-link-0" href="/">
# <img alt="Casas en venta y renta en México - icasas.mx" class="logo" itemprop="logo" src="https://script.resemmedia.com/images/images/logo-icasas_v4.png"/>
# <meta content="https://www.icasas.mx/" itemprop="url"/>
# </a>
# </div>
# </div>
# <i class="icon-r-menu" id="openHeaderMenuMobile"></i>
# <ul class="items-list"><li class="items-list__item">
# <div class="js-dropdown modulo dropdown blue">
# <button class="dropdown__btn-select" type="button">
# <span class="text">MX$</span>
# </button>
# <ul class="dropdown__list alt-col js-nice">
# <li class="dropdown__list__item currency-selector" data-id="" data-val="MXN">MX$</li>
# <li class="dropdown__list__item currency-selector" data-id="" data-val="USD">US$</li></ul>
# </div>
# </li><li class="items-list__item">
# <a class="icon login" href="#">
# <span class="text ui-text-white-1" data-login="Login" data-my-account="Mi cuenta">Login</span>
# <span class="icon-r-user login"></span>
# </a>
# </li></ul>
# </div></header>
# <div id="g_prompt" style="position:absolute; float:right; top:25px;"></div>
# <div class="menu">
# <div class="menu__arrow">
# <a class="ui-link-0" href="#">
# <div></div>
# </a>
# </div>
# <div class="menu__title">
# <p class="ui-titular-1">Iniciar sesión en Icasas México</p>
# </div>
# <div class="menu__login">
# <form action="/clientLoginServlet" class="login" method="post">
# <div class="login__title ui-titular-2">Cuenta de usuario</div>
# <div class="login__wrapper">
# <p class="error display-none" id="loginFail"></p>
# <div class="input-form">
# <input id="loginMail" name="email" placeholder="Email" type="email" value=""/></div>
# <div class="input-form">
# <input id="loginPassword" name="pwd" placeholder="Contraseña" type="password"/>
# </div>
# <div class="input-form">
# <button class="ui-button-1" id="loginButton">Ingresar</button>
# </div>
# <!-- 				<div class="g-signin2" data-width="300" data-height="40" data-longtitle="true" data-theme="dark" data-onsuccess="gSignIn" async defer></div> -->
# <div async="" defer="" id="myGoogleButton"></div>
# <div class="input-form text-center">
# <a class="ui-text-grey-1" id="recoverPassword">Recuperar contraseña</a>
# </div>
# </div>
# </form>
# </div>
# <div class="menu__registration">
# <span class="ui-text-grey-1">¿Necesitas una cuenta?</span>
# <a class="ui-text-blue-1" data-where="listing" id="signUp">Registrarse</a>
# </div>
# </div>
# <script>
# 		var loginButtonTextLogin = 'Login';
# 		var loginButtonTextMyaccount = 'Mi cuenta';
# 	</script>
# <nav class="migas" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <ul class="detail-pagination">
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/" itemprop="item" title="icasas"><span itemprop="name">icasas</span><i class="icon-r-chevron-right"></i></a>
# <meta content="1" itemprop="position"/>
# </li>
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/renta/comerciales-oficinas-3_14_0_0_0_0" itemprop="item" title="Oficinas en Renta"><span itemprop="name">Oficinas en Renta</span><i class="icon-r-chevron-right"></i></a>
# <meta content="2" itemprop="position"/>
# </li>
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/renta/comerciales-oficinas-guerrero-3_14_12_0_0_0" itemprop="item" title="Guerrero"><span itemprop="name">Guerrero</span><i class="icon-r-chevron-right"></i></a>
# <meta content="3" itemprop="position"/>
# </li>
# <li class="elementBC detail-bread-li" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0" itemprop="item" title="Acapulco de Juárez"><span itemprop="name">Acapulco de Juárez</span><i class="icon-r-chevron-right"></i></a>
# <meta content="4" itemprop="position"/>
# </li>
# </ul>
# </nav>
# <div class="container-body listado">
# <div class="aside">
# <div class="alert floating-alert desktop">
# <span class="text-hide">Te avisamos de nuevos anuncios en tu mail:</span>
# <button class="create-alert-visitor" data-origin="LB" data-text="Crear alerta" data-text-small="Crear alerta"></button>
# </div>
# <aside class="filtro">
# <div class="cabeza">
# <div class="filtrar">FILTRA TU BÚSQUEDA<i class="icon-r-cross cerrar-filtro"></i></div>
# </div>
# <div class="filtro-wrapper">
# <form class="ui-form-1">
# <div class="regiones-wrapper mostrar provincia-dropw" data-ae="location">
# <div class="regiones-pestana provincia-dropp">
# <h3 class="title">Barrio
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d61636170756c636f2d6a756172657a2d63656e74726f2d335f31345f31325f305f3336365f343431">
# <label class="labe1" for="checkbox-7386"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-acapulco-juarez-centro-3_14_12_0_366_441" title="Acapulco de Juárez Centro">Acapulco de Juárez Centro (2)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d636f6e646573612d335f31345f31325f305f3336365f32393738">
# <label class="labe1" for="checkbox-12021"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-condesa-3_14_12_0_366_2978" title="Condesa">Condesa (1)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d636f7374612d617a756c2d335f31345f31325f305f3336365f313030">
# <label class="labe1" for="checkbox-12224"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-costa-azul-3_14_12_0_366_100" title="Costa Azul">Costa Azul (2)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d686f726e6f732d696e73757267656e7465732d335f31345f31325f305f3336365f31373039">
# <label class="labe1" for="checkbox-17139"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-hornos-insurgentes-3_14_12_0_366_1709" title="Hornos Insurgentes">Hornos Insurgentes (3)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d6d6167616c6c616e65732d335f31345f31325f305f3336365f32393732">
# <label class="labe1" for="checkbox-23745"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-magallanes-3_14_12_0_366_2972" title="Magallanes">Magallanes (2)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d6e7565766f2d63617961636f2d335f31345f31325f305f3336365f3131333437">
# <label class="labe1" for="checkbox-25643"></label>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-nuevo-cayaco-3_14_12_0_366_11347" title="Nuevo Cayaco">Nuevo Cayaco (2)
#                     </a>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper mostrar tipo-dropw" data-ae="type">
# <div class="regiones-pestana tipo-dropp">
# <h3 class="title">Tipo de inmueble
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d656469666963696f732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31355f31325f305f3336365f30">
# <label class="labe1" for="checkbox-15"></label>
# <a class="linkFilter" href="/renta/comerciales-edificios-guerrero-acapulco-juarez-3_15_12_0_366_0" title="Edificio">Edificios (7)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d677565727265726f2d61636170756c636f2d6a756172657a2d325f305f31325f305f3336365f30">
# <label class="labe1" for="checkbox-2"></label>
# <a class="linkFilter" href="/renta/habitacionales-guerrero-acapulco-juarez-2_0_12_0_366_0" title="Habitacional">Habitacionales (1,939)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d696e6d7565626c65732d70726f6475637469766f732d757262616e6f732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31375f31325f305f3336365f30">
# <label class="labe1" for="checkbox-17"></label>
# <a class="linkFilter" href="/renta/comerciales-inmuebles-productivos-urbanos-guerrero-acapulco-juarez-3_17_12_0_366_0" title="Inmuebles productivos urbanos">Inmuebles productivos urbanos (3)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6c6f63616c65732d636f6d65726369616c65732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31305f31325f305f3336365f30">
# <label class="labe1" for="checkbox-10"></label>
# <a class="linkFilter" href="/renta/comerciales-locales-comerciales-guerrero-acapulco-juarez-3_10_12_0_366_0" title="Local comercial">Locales Comerciales (227)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f746965727261732d6c6f7465732d74657272656e6f732d677565727265726f2d61636170756c636f2d6a756172657a2d355f395f31325f305f3336365f30">
# <label class="labe1" for="checkbox-9"></label>
# <a class="linkFilter" href="/renta/tierras-lotes-terrenos-guerrero-acapulco-juarez-5_9_12_0_366_0" title="Lote de Terreno">Lotes de Terrenos (37)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f696e647573747269616c65732d6e617665732d677565727265726f2d61636170756c636f2d6a756172657a2d345f32305f31325f305f3336365f30">
# <label class="labe1" for="checkbox-20"></label>
# <a class="linkFilter" href="/renta/industriales-naves-guerrero-acapulco-juarez-4_20_12_0_366_0" title="Nave">Naves (28)
#                     </a>
# </li>
# <li class="regiones iCheck">
# <label class="labe1 checkSelected" for="checkbox-14"></label>
# <span class="spanFilter" title="Oficina">Oficinas (32)</span>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper mostrar sudtipo-dropw" data-ae="subtype">
# <div class="regiones-pestana sudtipo-dropp">
# <h3 class="title">Otros tipos de propiedad
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d63617361732d677565727265726f2d61636170756c636f2d6a756172657a2d325f355f31325f305f3336365f30">
# <label class="labe1" for="checkbox-5"></label>
# <a class="linkFilter" href="/renta/habitacionales-casas-guerrero-acapulco-juarez-2_5_12_0_366_0" title="Casa">Casas (687)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d63617361732d636f6e646f6d696e696f2d677565727265726f2d61636170756c636f2d6a756172657a2d325f375f31325f305f3336365f30">
# <label class="labe1" for="checkbox-7"></label>
# <a class="linkFilter" href="/renta/habitacionales-casas-condominio-guerrero-acapulco-juarez-2_7_12_0_366_0" title="Casa en condominio">Casas condominio (57)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d646570617274616d656e746f732d677565727265726f2d61636170756c636f2d6a756172657a2d325f335f31325f305f3336365f30">
# <label class="labe1" for="checkbox-3"></label>
# <a class="linkFilter" href="/renta/habitacionales-departamentos-guerrero-acapulco-juarez-2_3_12_0_366_0" title="Departamento">Departamentos (1,153)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d7175696e7461732d677565727265726f2d61636170756c636f2d6a756172657a2d325f345f31325f305f3336365f30">
# <label class="labe1" for="checkbox-4"></label>
# <a class="linkFilter" href="/renta/habitacionales-quintas-guerrero-acapulco-juarez-2_4_12_0_366_0" title="Quinta">Quintas (13)
#                     </a>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f68616269746163696f6e616c65732d76696c6c61732d677565727265726f2d61636170756c636f2d6a756172657a2d325f315f31325f305f3336365f30">
# <label class="labe1" for="checkbox-1"></label>
# <a class="linkFilter" href="/renta/habitacionales-villas-guerrero-acapulco-juarez-2_1_12_0_366_0" title="Villa">Villas (29)
#                     </a>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper mostrar confoto" data-ae="other">
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f666f746f73">
# <label class="labe1" for="checkbox-1640973216670"></label>
# <span class="spanFilter" title="Fotos">Fotos</span>
# </li>
# </ul>
# </div>
# <div class="precios-wrapper" id="precios-wrapper">
# <div class="regiones-wrapper preciomax" data-ae="priceMin">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Precio Mín.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="priceMin" name="priceMin" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="price-min">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d70726563696f" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d70726563696f" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d70726563696f" title="1,000">1,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313530302d70726563696f" title="1,500">1,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f323030302d70726563696f" title="2,000">2,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f323530302d70726563696f" title="2,500">2,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f333030302d70726563696f" title="3,000">3,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f333530302d70726563696f" title="3,500">3,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f343030302d70726563696f" title="4,000">4,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f353030302d70726563696f" title="5,000">5,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f373030302d70726563696f" title="7,000">7,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31303030302d70726563696f" title="10,000">10,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31323030302d70726563696f" title="12,000">12,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31353030302d70726563696f" title="15,000">15,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f31373030302d70726563696f" title="17,000">17,000</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="regiones-wrapper preciomax" data-ae="priceMax">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Precio Máx.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="priceMax" name="priceMax" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="price-max">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d3230302d70726563696f" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d3530302d70726563696f" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d313030302d70726563696f" title="1,000">1,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d313530302d70726563696f" title="1,500">1,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d323030302d70726563696f" title="2,000">2,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d323530302d70726563696f" title="2,500">2,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d333030302d70726563696f" title="3,000">3,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d333530302d70726563696f" title="3,500">3,500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d343030302d70726563696f" title="4,000">4,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d353030302d70726563696f" title="5,000">5,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d373030302d70726563696f" title="7,000">7,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31303030302d70726563696f" title="10,000">10,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31323030302d70726563696f" title="12,000">12,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31353030302d70726563696f" title="15,000">15,000</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f302d31373030302d70726563696f" title="17,000">17,000</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="precios-wrapper" id="surface-wrapper">
# <div class="regiones-wrapper preciomax" data-ae="surfaceMin">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Área Min.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="surfaceMin" name="surfaceMin" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="surface-min">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f35302d6d32" title="50">50</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3130302d6d32" title="100">100</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3135302d6d32" title="150">150</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d6d32" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3235302d6d32" title="250">250</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3330302d6d32" title="300">300</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d6d32" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d6d32" title="1,000">1,000</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="regiones-wrapper preciomax" data-ae="surfaceMax">
# <div class="regiones-pestana preciomax-dropp">
# <h3 class="title">Área Máx.
#                         </h3>
# </div>
# <input class="buscador buscadorprice integer-input" id="surfaceMax" name="surfaceMax" placeholder="" type="search" value=""/>
# <div class="filter-dropdown" data-where="surface-max">
# <ul>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f35302d6d32" title="50">50</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3130302d6d32" title="100">100</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3135302d6d32" title="150">150</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3230302d6d32" title="200">200</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3235302d6d32" title="250">250</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3330302d6d32" title="300">300</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f3530302d6d32" title="500">500</span>
# </li>
# <li class="dropdown-price">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f313030302d6d32" title="1,000">1,000</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="prestas-flex">
# <div class="regiones-wrapper presta-dropw mostrar" data-ae="rooms">
# <div class="regiones-pestana presta-dropp">
# <div class="title"><i class="icon-r-bed"></i></div>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f312d726563616d617261">
# <label class="labe1" for="checkbox-1"></label>
# <span class="spanFilter" title="1">1</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f322d726563616d61726173">
# <label class="labe1" for="checkbox-2"></label>
# <span class="spanFilter" title="2">2</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f332d726563616d61726173">
# <label class="labe1" for="checkbox-3"></label>
# <span class="spanFilter" title="3">3</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f342d726563616d61726173">
# <label class="labe1" for="checkbox-4"></label>
# <span class="spanFilter" title="4">4</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f352d726563616d61726173">
# <label class="labe1" for="checkbox-5"></label>
# <span class="spanFilter" title="5">5</span>
# </li>
# </ul>
# </div>
# <div class="regiones-wrapper presta-dropw mostrar" data-ae="bathrooms">
# <div class="regiones-pestana presta-dropp">
# <div class="title"><i class="icon-r-bathroom"></i></div>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f312d62616e6f">
# <label class="labe1" for="checkbox-1"></label>
# <span class="spanFilter" title="1">1</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f322d62616e6f73">
# <label class="labe1" for="checkbox-2"></label>
# <span class="spanFilter" title="2">2</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f332d62616e6f73">
# <label class="labe1" for="checkbox-3"></label>
# <span class="spanFilter" title="3">3</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f342d62616e6f73">
# <label class="labe1" for="checkbox-4"></label>
# <span class="spanFilter" title="4">4</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f352d62616e6f73">
# <label class="labe1" for="checkbox-5"></label>
# <span class="spanFilter" title="5">5</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="regiones-wrapper mostrar sudtipo-dropw" data-ae="dateeAdded">
# <div class="regiones-pestana sudtipo-dropp">
# <h3 class="title">Fecha de publicación
#                     </h3>
# <i class="icon-r-chevron-down imgrotate"></i>
# </div>
# <ul class="regiones-container">
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f30">
# <label class="labe1 checkSelected" for="checkbox-1640973216676"></label>
# <span class="spanFilter" title="Indiferente">Indiferente</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f756c74696d61732d34382d686f7261732d7075626c69636163696f6e">
# <label class="labe1" for="checkbox-1640973216677"></label>
# <span class="spanFilter" title="Últimas 48 horas">Últimas 48 horas</span>
# </li>
# <li class="regiones iCheck uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f665f756c74696d612d73656d616e612d7075626c69636163696f6e">
# <label class="labe1" for="checkbox-1640973216678"></label>
# ...
# <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjMxMTU4Ly0xMTY0NjAxMzg4LmpwZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=)">
# <div class="slider-cta-overlay-back"></div>
# <p>¿Te gusta?</p><button class="slider-main-cta btn-contact" data-adid="3036354" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">Contactar</button><button class="slider-secondary-cta" data-type="carousel">Ver en detalle</button>
# </div>
# </div><section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork"><meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjMxMTU4Ly0xMTY0NjAxMzg4LmpwZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" itemprop="url"/></section>
# <span class="slider-chevron left"></span><span class="slider-chevron right"></span>
# <div class="icons"> <span class="icon photo" data-total="4"><span class="current">1</span>/<span class="total">4</span></span> </div>
# </div>
# <div class="ad-data">
# <div class="data">
# <div class="price">				13,500 MX$			</div>
# <h2 class="title" itemprop="name"><a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/oficina-renta-costa-azul_3036354" itemprop="url">Oficina en Renta Acapulco De Juárez, Guerrero</a></h2>
# <p class="description" itemprop="description">Oficina en renta en el interior de la plaza pabellón costera, cuenta con vigilancia muy cerca de centros comerciales, cine...</p>
# <div class="adCharacteristics">
# <span class="numbers"> <span class="areaBuilt">50m2</span> </span>
# </div>
# </div>
# <div class="actions">
# <span class="like heart-login" data-adid="3036354" data-text="Favorito"></span>
# <div class="buttons"> <button class="btn-phone" data-adid="3036354" data-partner="Berenice Montejano" data-where="listing">Llamar</button>
# <button class="btn-contact" data-adid="3036354" data-where="listing">Contactar</button>
# </div>
# </div>
# </div>
# <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress"><meta content="MX" itemprop="addressCountry"/><meta content="Acapulco de Juárez" itemprop="addressLocality"/><meta content="Guerrero" itemprop="addressRegion"/><meta content="" itemprop="streetAddress"/></span>
# </li>
# <li class="ad" data-ev="0000343434363934392d31323031372d312d3239" id="4446949" itemscope="" itemtype="https://schema.org/Residence">
# <div class="ad-ph">
# <div class="slider-ad">
# <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" class="ill" data-src="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/><img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzkxNzY5NjcyNS5qcGVnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjoyNjYsImhlaWdodCI6MjEwLCJmaXQiOiJjb3ZlciIsIndpdGhvdXRFbmxhcmdlbWVudCI6dHJ1ZX19fQ==" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/><img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEwNTI1MTc3MTcuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
# <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19)">
# <div class="slider-cta-overlay-back"></div>
# <p>¿Te gusta?</p><button class="slider-main-cta btn-contact" data-adid="4446949" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">Contactar</button><button class="slider-secondary-cta" data-type="carousel">Ver en detalle</button>
# </div>
# </div><section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork"><meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0xOTQ0NDYwMDk3LmpwZWciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjI2NiwiaGVpZ2h0IjoyMTAsImZpdCI6ImNvdmVyIiwid2l0aG91dEVubGFyZ2VtZW50Ijp0cnVlfX19" itemprop="url"/></section>
# <span class="slider-chevron left"></span><span class="slider-chevron right"></span>
# <div class="icons"> <span class="icon photo" data-total="3"><span class="current">1</span>/<span class="total">3</span></span> </div>
# </div>
# <div class="ad-data">
# <div class="data">
# <div class="price">				3,600 MX$			</div>
# <h2 class="title" itemprop="name"><a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/renta-oficina-hornos-insurgentes-acapulco-gro_4446949" itemprop="url">Oficina en Renta Hornos Insurgentes, Acapulco De Juárez</a></h2>
# <p class="description" itemprop="description">En renta oficina con excelente ubicación. La oficina cuenta con interfon, un baño para hombres y un baño para mujeres en ...</p>
# <div class="adCharacteristics">
# <span class="numbers"> <span class="areaBuilt">40m2</span> <span class="bathrooms">2<i class="icon-r-bathroom"></i></span> </span>
# </div>
# </div>
# <div class="actions">
# <span class="like heart-login" data-adid="4446949" data-text="Favorito"></span>
# <div class="buttons"> <button class="btn-phone" data-adid="4446949" data-partner="Century 21 Lacunza &amp; Asociados" data-where="listing">Llamar</button>
# <button class="btn-contact" data-adid="4446949" data-where="listing">Contactar</button>
# </div>
# </div>
# </div>
# <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress"><meta content="MX" itemprop="addressCountry"/><meta content="Hornos Insurgentes, Acapulco de Juárez" itemprop="addressLocality"/><meta content="Guerrero" itemprop="addressRegion"/><meta content="" itemprop="streetAddress"/></span>
# </li>
# <li class="ad" data-ev="0000343434363934372d31323031372d312d3330" id="4446947" itemscope="" itemtype="https://schema.org/Residence">
# <div class="ad-ph">
# <div class="slider-ad">
# <img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" class="ill" data-src="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/><img alt="Oficina en Renta Hornos Insurgentes, Acapulco De Juárez" data-lazy="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3Ly0yNzE2NzQ3NTMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" src="https://script.resemmedia.com/images/images/loading-image-v2.svg"/>
# <div class="slider-cta" style="background-image: url(https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=)">
# <div class="slider-cta-overlay-back"></div>
# <p>¿Te gusta?</p><button class="slider-main-cta btn-contact" data-adid="4446947" data-contactsubtype="ADS_LISTING_CAROUSEL" data-where="listing-carousel">Contactar</button><button class="slider-secondary-cta" data-type="carousel">Ver en detalle</button>
# </div>
# </div><section itemprop="photo" itemscope="" itemtype="https://schema.org/CreativeWork"><meta content="https://d2op7us8chplo5.cloudfront.net/eyJidWNrZXQiOiJyZXNlbS1teCIsImtleSI6IjEyMDE3LzEyMjM4Mjc2NjMuanBlZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6MjY2LCJoZWlnaHQiOjIxMCwiZml0IjoiY292ZXIiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=" itemprop="url"/></section>
# <span class="slider-chevron left"></span><span class="slider-chevron right"></span>
# <div class="icons"> <span class="icon photo" data-total="2"><span class="current">1</span>/<span class="total">2</span></span> </div>
# </div>
# <div class="ad-data">
# <div class="data">
# <div class="price">				3,000 MX$			</div>
# <h2 class="title" itemprop="name"><a class="detail-redirection" href="/renta/oficinas-guerrero-acapulco-juarez/renta-oficina-hornos-insurgentes_4446947" itemprop="url">Oficina en Renta Hornos Insurgentes, Acapulco De Juárez</a></h2>
# <p class="description" itemprop="description">En renta oficina con excelente ubicación. La oficina cuenta con interfon, así como 2 baños , un baño para hombres y otro ...</p>
# <div class="adCharacteristics">
# <span class="numbers"> <span class="areaBuilt">39m2</span> <span class="bathrooms">2<i class="icon-r-bathroom"></i></span> </span>
# </div>
# </div>
# <div class="actions">
# <span class="like heart-login" data-adid="4446947" data-text="Favorito"></span>
# <div class="buttons"> <button class="btn-phone" data-adid="4446947" data-partner="Century 21 Lacunza &amp; Asociados" data-where="listing">Llamar</button>
# <button class="btn-contact" data-adid="4446947" data-where="listing">Contactar</button>
# </div>
# </div>
# </div>
# <span itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress"><meta content="MX" itemprop="addressCountry"/><meta content="Hornos Insurgentes, Acapulco de Juárez" itemprop="addressLocality"/><meta content="Guerrero" itemprop="addressRegion"/><meta content="" itemprop="streetAddress"/></span>
# </li>
# </ul>
# <ul aria-label="Pagination" class="pagination" data-tp="2" role="menubar"><li class="current"><span>1</span></li><li>
# <a class="linkFilter" href="/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0/p_2" title="2">2
# </a>
# </li><li class="next">
# <span class="spanFilter uExternalRefresh" id="2f72656e74612f636f6d65726369616c65732d6f666963696e61732d677565727265726f2d61636170756c636f2d6a756172657a2d335f31345f31325f305f3336365f302f705f32" title="Siguiente">Siguiente</span>
# </li></ul>
# </article>
# </div>
# <section class="pop-up-contacto">
# </section>
# <footer>
# <div class="footer-content">
# <div class="footer-left">
# <ul>
# <li><a href="https://www.icasas.mx/noticias/">Blog</a></li>
# <li><a href="/quienesSomos">Quiénes somos</a></li>
# <li><a href="/politicaPrivacidad">Política de Privacidad</a></li>
# <li><a href="/politicaCookies">Política de Cookies</a></li>
# <li><a href="/contactanos">Contacta con icasas</a></li>
# </ul>
# <ul>
# <li><a class="publishYourProperty" href="/redirectCreateAdServlet">Publicar tu anuncio</a></li>
# <li><a href="/publicar/desarrolladora">Publicar como desarrolladora</a></li>
# <li><a href="/publicar/agencia">Publicar como profesional inmobiliario</a></li>
# <li><a href=""></a></li>
# <li><a href=""></a></li>
# </ul>
# </div>
# <div class="footer-right">
# <strong>icasas por todo el mundo</strong>
# <div class="footer-worldwide">
# <ul class="continent">
# <li><strong>América</strong></li>
# <li><a href="https://www.icasas.com.ar">Argentina</a></li>
# <li><a href="https://www.imocasa.com.br">Brasil</a></li>
# <li><a href="https://www.icasas.cl">icasas Chile</a></li>
# <li><a href="https://www.puntopropiedad.com">Colombia</a></li>
# </ul>
# <ul class="continent">
# <li><strong> </strong></li>
# <li><a href="https://www.icasas.co.cr/">Costa Rica</a></li>
# <li><a href="https://www.icasas.ec">Ecuador</a></li>
# <li><a href="https://www.icasas.mx">México</a></li>
# <li><a href="https://www.icasas.com.pa/">Panamá</a></li>
# <li><a href="https://www.laencontre.com.pe/">LaEncontre Perú</a></li>
# </ul>
# <ul class="continent">
# <li><strong>África</strong></li>
# <li><a href="http://www.persquare.co.za">Sudáfrica</a></li>
# </ul>
# <ul class="continent">
# <li><strong>Europa</strong></li>
# <li><a href="https://www.globaliza.com">España</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer-network">
# <div class="network-app">
# <p class="network-text">Descarga nuestra app</p>
# <a class="footer-app-icon google" href="https://play.google.com/store/apps/details?id=com.resem.app.mx"></a>
# </div>
# <div class="network-social">
# <p class="network-text">Entérate de las últimas novedades</p>
# <a class="footer-icon twitter" href="https://twitter.com/icasasmex" target="_blank"></a>
# <a class="footer-icon face" href="https://www.facebook.com/icasasmexico" target="_blank"></a>
# </div>
# </div>
# <div class="copyright">
# <span><strong>icasas</strong> Copyright 2021</span>
# </div>
# <script type="text/javascript">
# 		var g_client_id = '948427263315-8rtput7qre769n9nfd95r8skldfobek1.apps.googleusercontent.com';
# 		var cIso = 'MX';
# 	</script>
# </footer>
# <script defer="">
# 		var decimalSeparator='.';
# 		var groupingSeparator=',';
# 		var alertCreated = 'Alerta creada correctamente';var alertExistsText = 'Ya existe una alerta creada para esta búsqueda';
# 		var operationType='renta';
# 		var urlRequest ="";
#    		var callButtonText = "Llamar";
#    		var processingText = "Procesando...";
# 		var landingZoneSubUrl='zona';
# 		var language="es";
# 			urlRequest = '/renta/comerciales-oficinas-guerrero-acapulco-juarez-3_14_12_0_366_0';
# 		var pushNotificationsConfig = {
#   "enabled" : false,
#   "publicKey" : null
# }
#   	</script><script src="https://script.resemmedia.com/script/script/listing.min_v136.js" type="text/javascript"></script>
# <!--[if lt IE 9]>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/make_ie8_work.js"></script>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/modernizr.custom.84408.js"></script>
#   <script type='text/javascript' src="/www/resem/new_design/detail/js/lib/selectivizr-min.js"></script>
# <![endif]-->
# <script defer="" type="text/javascript">
# analytics.setDimension('dimension1', 'anonimo');
# </script>
# <script defer="" type="text/javascript">
#
# 		analytics.setContent('contentGroup1', 'Guerrero-Acapulco de Juárez');
#
# 		analytics.setContent('contentGroup2', 'Zona');
#
# 	analytics.setContent('contentGroup3', 'oficina_renta');
#
# 	analytics.setContent('contentGroup4', 'listado_inmueble');
#
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-401688055"></script>
# <script>
#     var googleConversion = {
#         accountId: 'AW-401688055',
#         agencyConversionLabel: 'LsLFCJmP6f0BEPeLxb8B',
#         developerConversionLabel: 'wd1CCIfYts0CEPeLxb8B'
#     }
#
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', googleConversion.accountId);
#
#     function goog_report_conversion(type) {
#         if (type === undefined || type === "")  {
#             return;
#         }
#
#         var conversionLabel = googleConversion.agencyConversionLabel;
#         if(type === "developer") {
#             conversionLabel = googleConversion.developerConversionLabel;
#         }
#
#         let sendTo = googleConversion.accountId + "/" + conversionLabel;
#
#         gtag('event', 'conversion', {
#             'send_to': sendTo,
#             'event_callback': function() {}
#         });
#         return false;
#     }
# </script>
# <script defer="">
#
# 	analytics.contactRTB = true;
#
# 	analytics.send();
# </script>
# <iframe frameborder="0" height="1" scrolling="no" src="https://us.creativecdn.com/tags?id=pr_pHEG9OrA1ehGHoWzx1uu_listing_2405979,1851747,1851749,1851751,4149910" style="display: none;" width="1"></iframe>
# <div id="recaptchaPhone"></div>
# <input name="recaptchaSiteKey" type="hidden" value="6LcRZXoUAAAAAHseVHQSwR9Z7KSMT81ABP0yAeCO"/><link href="https://script.resemmedia.com/style/style/listing.min_v99.css" rel="stylesheet"/>
# <script type="text/javascript">
# 		$(document).ready(function(){
# 			if ($("input[id^='contact-phone'], input[id^='phone-']").length>0) {
# 				jsUtils.loadDialCodeCountries(cIso);
# 			}
# 			$("#g_prompt").css("left", $("header a.login").get(0).getBoundingClientRect().left - 330);
# 		});
# 	</script>
# </body></html>>

# %% [markdown]
# safsdvSD
